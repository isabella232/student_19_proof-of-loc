# %% [markdown]
# # Fixed Lies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("data/fixed_lies/test_map_lies_to_effects_100.csv")

# %%
data["grouped"] = list(zip(data.is_liar, data.is_blacklisted))
grouped_data = data[["node", "grouped"]]

# %%
grouped_by_node = grouped_data.groupby("node").agg(lambda x: set(x.values.tolist()))

# %%
grouped_by_node["nb_situations"] = grouped_by_node['grouped'].map(lambda x: len(x))

# %%
grouped_by_node.sort_values(by="nb_situations", ascending=False)
# Out:
#                              grouped  nb_situations
# node
# N0     {(True, False), (True, True)}              2
# N2     {(True, False), (True, True)}              2
# N64   {(False, False), (True, True)}              2
# N32   {(False, False), (True, True)}              2
# N31   {(False, False), (True, True)}              2
# N26    {(True, False), (True, True)}              2
# N25    {(True, False), (True, True)}              2
# N22    {(True, False), (True, True)}              2
# N99   {(False, False), (True, True)}              2
# N10    {(True, False), (True, True)}              2
# N17                  {(True, False)}              1
# N7                    {(True, True)}              1
# N77                 {(False, False)}              1
# N76                 {(False, False)}              1
# N75                 {(False, False)}              1
# N74                 {(False, False)}              1
# N73                 {(False, False)}              1
# N72                 {(False, False)}              1
# N71                 {(False, False)}              1
# N70                 {(False, False)}              1
# N69                 {(False, False)}              1
# N79                 {(False, False)}              1
# N68                 {(False, False)}              1
# N67                 {(False, False)}              1
# N66                 {(False, False)}              1
# N65                 {(False, False)}              1
# N63                 {(False, False)}              1
# N62                 {(False, False)}              1
# N61                 {(False, False)}              1
# N60                 {(False, False)}              1
# ...                              ...            ...
# N23                   {(True, True)}              1
# N15                  {(True, False)}              1
# N21                   {(True, True)}              1
# N20                   {(True, True)}              1
# N16                  {(True, False)}              1
# N19                  {(True, False)}              1
# N36                 {(False, False)}              1
# N38                 {(False, False)}              1
# N57                 {(False, False)}              1
# N39                 {(False, False)}              1
# N56                 {(False, False)}              1
# N55                 {(False, False)}              1
# N1                    {(True, True)}              1
# N53                 {(False, False)}              1
# N52                 {(False, False)}              1
# N51                 {(False, False)}              1
# N50                 {(False, False)}              1
# N5                    {(True, True)}              1
# N49                 {(False, False)}              1
# N48                 {(False, False)}              1
# N47                 {(False, False)}              1
# N46                 {(False, False)}              1
# N45                 {(False, False)}              1
# N44                 {(False, False)}              1
# N43                 {(False, False)}              1
# N42                 {(False, False)}              1
# N41                 {(False, False)}              1
# N40                 {(False, False)}              1
# N4                   {(True, False)}              1
# N54                 {(False, False)}              1
#
# [100 rows x 2 columns]

# %%
data[["node", "is_liar", "is_blacklisted"]].groupby(["is_liar", "is_blacklisted"]).count()
# Out:
#                         node
# is_liar is_blacklisted
# False   False           6700
# True    False           1244
#         True            2056

# %%
lie_effects = data[["lie", "is_blacklisted"]][data["lie"] > 0]

# %%
lie_effects
# Out:
#         lie  is_blacklisted
# 0     13682           False
# 1     31204            True
# 2     19230           False
# 3     47099            True
# 4     27610           False
# 5      1256            True
# 6     32233           False
# 7     13305            True
# 8      3304           False
# 9     23091            True
# 10    26634            True
# 11     8928            True
# 12    27226            True
# 13    39831           False
# 14    49161           False
# 15    43564           False
# 16    13135           False
# 17     1150           False
# 18    49568            True
# 19    35163           False
# 20    31165            True
# 21    34382            True
# 22    19962            True
# 23    37817            True
# 24    13976            True
# 25    37227            True
# 26     8541            True
# 27    31441           False
# 28     9342            True
# 29     3622            True
# ...     ...             ...
# 9903  47099            True
# 9904  27610           False
# 9905   1256            True
# 9906  32233           False
# 9907  13305            True
# 9908   3304           False
# 9909  23091            True
# 9910  26634           False
# 9911   8928            True
# 9912  27226            True
# 9913  39831           False
# 9914  49161           False
# 9915  43564           False
# 9916  13135           False
# 9917   1150           False
# 9918  49568            True
# 9919  35163           False
# 9920  31165            True
# 9921  34382            True
# 9922  19962            True
# 9923  37817            True
# 9924  13976            True
# 9925  37227            True
# 9926   8541            True
# 9927  31441           False
# 9928   9342            True
# 9929   3622            True
# 9930  35447            True
# 9932  24465            True
# 9964  23865            True
#
# [3300 rows x 2 columns]

# %%
lie_effects.groupby("lie").agg(lambda x: set(x.values.tolist())).reset_index().sort_values(by="lie")
# Out:
#       lie is_blacklisted
# 0    1150        {False}
# 1    1256         {True}
# 2    1579  {False, True}
# 3    1668        {False}
# 4    2210        {False}
# 5    2270         {True}
# 6    2514        {False}
# 7    3304        {False}
# 8    3622         {True}
# 9    3647        {False}
# 10   5772  {False, True}
# 11   7055        {False}
# 12   7184         {True}
# 13   8541  {False, True}
# 14   8563        {False}
# 15   8796        {False}
# 16   8928         {True}
# 17   9342         {True}
# 18   9825  {False, True}
# 19   9971         {True}
# 20   9973         {True}
# 21  10529        {False}
# 22  10585        {False}
# 23  10789        {False}
# 24  10932         {True}
# 25  11270         {True}
# 26  11598  {False, True}
# 27  13135        {False}
# 28  13305         {True}
# 29  13682        {False}
# ..    ...            ...
# 67  32603         {True}
# 68  32645        {False}
# 69  33494        {False}
# 70  34382         {True}
# 71  35159  {False, True}
# 72  35163        {False}
# 73  35447         {True}
# 74  37227  {False, True}
# 75  37380         {True}
# 76  37740        {False}
# 77  37817         {True}
# 78  38155         {True}
# 79  38798  {False, True}
# 80  39640        {False}
# 81  39831        {False}
# 82  40106         {True}
# 83  41334         {True}
# 84  42644         {True}
# 85  42742         {True}
# 86  42762        {False}
# 87  43564        {False}
# 88  43938         {True}
# 89  44133         {True}
# 90  45290        {False}
# 91  46145         {True}
# 92  47099         {True}
# 93  48488        {False}
# 94  48978        {False}
# 95  49161        {False}
# 96  49568         {True}
#
# [97 rows x 2 columns]

# %%
bl_by_lie = lie_effects.groupby(['lie', 'is_blacklisted']).size().unstack(fill_value=0).reset_index().sort_values(by="lie")

# %%
bl_by_lie
# Out:
# is_blacklisted    lie  False  True
# 0                1150    100     0
# 1                1256      0   100
# 2                1579      1     1
# 3                1668      1     0
# 4                2210      1     0
# 5                2270      0     1
# 6                2514      1     0
# 7                3304    100     0
# 8                3622      0   100
# 9                3647      1     0
# 10               5772      1     2
# 11               7055      1     0
# 12               7184      0     1
# 13               8541      3    97
# 14               8563      1     0
# 15               8796      1     0
# 16               8928      0   100
# 17               9342      0   100
# 18               9825      5     1
# 19               9971      0     3
# 20               9973      0     1
# 21              10529      1     0
# 22              10585      1     0
# 23              10789      1     0
# 24              10932      0     1
# 25              11270      0     1
# 26              11598      1     3
# 27              13135    100     0
# 28              13305      0   100
# 29              13682      3     0
# ..                ...    ...   ...
# 67              32603      0    11
# 68              32645      1     0
# 69              33494      1     0
# 70              34382      0   100
# 71              35159      1     2
# 72              35163    100     0
# 73              35447      0   100
# 74              37227     25    75
# 75              37380      0     1
# 76              37740      2     0
# 77              37817      0   100
# 78              38155      0     1
# 79              38798      7     2
# 80              39640      2     0
# 81              39831    100     0
# 82              40106      0     1
# 83              41334      0     1
# 84              42644      0     1
# 85              42742      0     3
# 86              42762      1     0
# 87              43564    100     0
# 88              43938      0     1
# 89              44133      0     1
# 90              45290      3     0
# 91              46145      0     1
# 92              47099      0    98
# 93              48488      1     0
# 94              48978      1     0
# 95              49161    100     0
# 96              49568      0   100
#
# [97 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 10))
bl_by_lie.plot(kind="bar", x="lie", ax=ax)

# %%
fig.savefig('graphs/fixed_lies/100_nodes_33_liars_100_sets.png')

# %%
bl_by_lie["Percentage"] = (bl_by_lie[True]/bl_by_lie[False]).replace([np.inf, -np.inf], 0.0)

# %%
bl_by_lie
# Out:
# is_blacklisted    lie  False  True  Percentage
# 0                1150    100     0    0.000000
# 1                1256      0   100    0.000000
# 2                1579      1     1    1.000000
# 3                1668      1     0    0.000000
# 4                2210      1     0    0.000000
# 5                2270      0     1    0.000000
# 6                2514      1     0    0.000000
# 7                3304    100     0    0.000000
# 8                3622      0   100    0.000000
# 9                3647      1     0    0.000000
# 10               5772      1     2    2.000000
# 11               7055      1     0    0.000000
# 12               7184      0     1    0.000000
# 13               8541      3    97   32.333333
# 14               8563      1     0    0.000000
# 15               8796      1     0    0.000000
# 16               8928      0   100    0.000000
# 17               9342      0   100    0.000000
# 18               9825      5     1    0.200000
# 19               9971      0     3    0.000000
# 20               9973      0     1    0.000000
# 21              10529      1     0    0.000000
# 22              10585      1     0    0.000000
# 23              10789      1     0    0.000000
# 24              10932      0     1    0.000000
# 25              11270      0     1    0.000000
# 26              11598      1     3    3.000000
# 27              13135    100     0    0.000000
# 28              13305      0   100    0.000000
# 29              13682      3     0    0.000000
# ..                ...    ...   ...         ...
# 67              32603      0    11    0.000000
# 68              32645      1     0    0.000000
# 69              33494      1     0    0.000000
# 70              34382      0   100    0.000000
# 71              35159      1     2    2.000000
# 72              35163    100     0    0.000000
# 73              35447      0   100    0.000000
# 74              37227     25    75    3.000000
# 75              37380      0     1    0.000000
# 76              37740      2     0    0.000000
# 77              37817      0   100    0.000000
# 78              38155      0     1    0.000000
# 79              38798      7     2    0.285714
# 80              39640      2     0    0.000000
# 81              39831    100     0    0.000000
# 82              40106      0     1    0.000000
# 83              41334      0     1    0.000000
# 84              42644      0     1    0.000000
# 85              42742      0     3    0.000000
# 86              42762      1     0    0.000000
# 87              43564    100     0    0.000000
# 88              43938      0     1    0.000000
# 89              44133      0     1    0.000000
# 90              45290      3     0    0.000000
# 91              46145      0     1    0.000000
# 92              47099      0    98    0.000000
# 93              48488      1     0    0.000000
# 94              48978      1     0    0.000000
# 95              49161    100     0    0.000000
# 96              49568      0   100    0.000000
#
# [97 rows x 4 columns]

# %%
fig1, ax1 = plt.subplots(figsize=(20, 10))
bl_by_lie[["Percentage", "lie"]].sort_values(by="lie").plot(kind="bar",x="lie", ax=ax1)
