# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
N = "200"
lie_type = "one_victim_uncoordinated"

# %%
statuses = {0: "no endpoint blacklisted", 1: "one endpoint blacklisted", 2: "both endpoints blacklisted"}
colors = {"no endpoint blacklisted": "green", 
          "one endpoint blacklisted": "blue", 
          "both endpoints blacklisted": "red"}

# %%
data= pd.read_csv("data/test_"+N+"_nodes_"+lie_type+".csv")[["true_latency", "recorded_latency", "blacklist_status"]]

# %%
data["status"] = data["blacklist_status"][data["blacklist_status"] > -1 ].map(statuses)

# %%
data
# Out:
#        true_latency  recorded_latency  blacklist_status  \
# 0               581               581                 0
# 1               887               887                 0
# 2               847               847                 0
# 3               559               559                 0
# 4               581               581                 0
# 5               818               818                 0
# 6               925               925                 0
# 7               540               540                 0
# 8               956               956                 0
# 9               800               800                 0
# 10              694               694                 0
# 11              511               511                 0
# 12              662               662                 0
# 13              589               589                 0
# 14              728               728                 0
# 15              774               774                 0
# 16              711               711                 0
# 17              945               945                 0
# 18              737               737                 0
# 19              606               606                 0
# 20              995               995                 0
# 21              966               966                 0
# 22              528               528                 0
# 23              758               758                 0
# 24              547               547                 0
# 25              947               947                 0
# 26              787               787                 0
# 27              888               888                 0
# 28              790               790                 0
# 29              515               515                 0
# ...             ...               ...               ...
# 19870           736               736                 0
# 19871           556               556                 0
# 19872           560               560                 0
# 19873           990               990                 0
# 19874           888               888                 0
# 19875           845               845                 0
# 19876           628               628                 0
# 19877           537               537                 0
# 19878           563               563                 0
# 19879           684               684                 0
# 19880           762               762                 0
# 19881           974               974                 0
# 19882           569               569                 0
# 19883           894               894                 0
# 19884           570               570                 0
# 19885           646               646                 0
# 19886           730               730                 0
# 19887           769               769                 0
# 19888           781               781                 0
# 19889           662               662                 0
# 19890           727               727                 0
# 19891           673               673                 0
# 19892           573               573                 0
# 19893           556               556                 0
# 19894           501               501                 0
# 19895           507               507                 0
# 19896           644               644                 0
# 19897           867               867                 0
# 19898           656               656                 0
# 19899           821               821                 0
#
#                         status
# 0      no endpoint blacklisted
# 1      no endpoint blacklisted
# 2      no endpoint blacklisted
# 3      no endpoint blacklisted
# 4      no endpoint blacklisted
# 5      no endpoint blacklisted
# 6      no endpoint blacklisted
# 7      no endpoint blacklisted
# 8      no endpoint blacklisted
# 9      no endpoint blacklisted
# 10     no endpoint blacklisted
# 11     no endpoint blacklisted
# 12     no endpoint blacklisted
# 13     no endpoint blacklisted
# 14     no endpoint blacklisted
# 15     no endpoint blacklisted
# 16     no endpoint blacklisted
# 17     no endpoint blacklisted
# 18     no endpoint blacklisted
# 19     no endpoint blacklisted
# 20     no endpoint blacklisted
# 21     no endpoint blacklisted
# 22     no endpoint blacklisted
# 23     no endpoint blacklisted
# 24     no endpoint blacklisted
# 25     no endpoint blacklisted
# 26     no endpoint blacklisted
# 27     no endpoint blacklisted
# 28     no endpoint blacklisted
# 29     no endpoint blacklisted
# ...                        ...
# 19870  no endpoint blacklisted
# 19871  no endpoint blacklisted
# 19872  no endpoint blacklisted
# 19873  no endpoint blacklisted
# 19874  no endpoint blacklisted
# 19875  no endpoint blacklisted
# 19876  no endpoint blacklisted
# 19877  no endpoint blacklisted
# 19878  no endpoint blacklisted
# 19879  no endpoint blacklisted
# 19880  no endpoint blacklisted
# 19881  no endpoint blacklisted
# 19882  no endpoint blacklisted
# 19883  no endpoint blacklisted
# 19884  no endpoint blacklisted
# 19885  no endpoint blacklisted
# 19886  no endpoint blacklisted
# 19887  no endpoint blacklisted
# 19888  no endpoint blacklisted
# 19889  no endpoint blacklisted
# 19890  no endpoint blacklisted
# 19891  no endpoint blacklisted
# 19892  no endpoint blacklisted
# 19893  no endpoint blacklisted
# 19894  no endpoint blacklisted
# 19895  no endpoint blacklisted
# 19896  no endpoint blacklisted
# 19897  no endpoint blacklisted
# 19898  no endpoint blacklisted
# 19899  no endpoint blacklisted
#
# [19900 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 10))
grouped = data.groupby('status')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='true_latency', y='recorded_latency', label=key, color=colors[key])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.show()

# %%
fig.savefig('graphs/'+N+'_nodes_' + lie_type+".png")
