# %% [markdown]
# # Graph for number of blacklisted liars when lies are fixed and number of liars increasing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#configs
lowerBoundLies = 1000  #lower bound on difference between true latency and lie told about it
upperBoundLies = 5000 #upper bound on difference between true latency and lie told about it
nbNodes = 100
maxNbLiars = 33
#lieClusterSizes = [5, 10, 20, 33]
nbLiarCombinations = 100 #nb different combinations of liars chosen throughout test
randomLiars = True      #whether the liars are chosen randomly or within same cluster
withSuspects = True     #activate enhanced blacklisting

random = "random_liars"
if not randomLiars:
    random = "clustered_liars"

filename = "test_" + str(nbNodes) + "_nodes_up_to_" + \
    str(maxNbLiars) + "_liars" +\
    "_var_liars_distance_" + str(upperBoundLies) +\
    "_" + random +\
    "_" + str(nbLiarCombinations) + "_combinations"

if withSuspects:
    filename += "_with_suspects"

# %%
data= pd.read_csv("data/"+filename+".csv")

# %%
data
# Out:
#         node  is_liar  is_blacklisted   lie  lieClusterSize
# 0         N0    False           False     0               5
# 1         N3    False           False     0               5
# 2         N4    False           False     0               5
# 3         N6    False           False     0               5
# 4         N7    False           False     0               5
# 5         N8    False           False     0               5
# 6         N9    False           False     0               5
# 7        N10    False           False     0               5
# 8        N11    False           False     0               5
# 9        N14    False           False     0               5
# 10       N16    False           False     0               5
# 11       N17    False           False     0               5
# 12       N18    False           False     0               5
# 13       N20    False           False     0               5
# 14       N21    False           False     0               5
# 15       N22    False           False     0               5
# 16       N23    False           False     0               5
# 17       N24    False           False     0               5
# 18       N25    False           False     0               5
# 19       N26    False           False     0               5
# 20       N27    False           False     0               5
# 21       N28    False           False     0               5
# 22       N29    False           False     0               5
# 23       N30    False           False     0               5
# 24       N32     True            True  3571               5
# 25       N32     True            True  2134               5
# 26       N32     True            True  1826               5
# 27       N32     True            True  3056               5
# 28       N32     True            True  2287               5
# 29       N32     True            True  1535               5
# ...      ...      ...             ...   ...             ...
# 1490670  N98     True            True  1379              33
# 1490671  N98     True            True  3090              33
# 1490672  N98     True            True  4720              33
# 1490673  N98     True            True  1166              33
# 1490674  N98     True            True  2598              33
# 1490675  N98     True            True  4479              33
# 1490676  N98     True            True  1281              33
# 1490677  N98     True            True  1315              33
# 1490678  N98     True            True  1666              33
# 1490679  N98     True            True  1589              33
# 1490680  N98     True            True  2885              33
# 1490681  N98     True            True  3078              33
# 1490682  N98     True            True  4724              33
# 1490683  N98     True            True  3042              33
# 1490684  N98     True            True  4026              33
# 1490685  N98     True            True  4611              33
# 1490686  N98     True            True  2306              33
# 1490687  N98     True            True  3110              33
# 1490688  N98     True            True  1478              33
# 1490689  N98     True            True  3711              33
# 1490690  N98     True            True  1759              33
# 1490691  N98     True            True  4760              33
# 1490692  N98     True            True  1268              33
# 1490693  N98     True            True  2898              33
# 1490694  N98     True            True  3692              33
# 1490695  N98     True            True  3359              33
# 1490696  N98     True            True  3444              33
# 1490697  N98     True            True  1414              33
# 1490698  N98     True            True  4844              33
# 1490699  N99    False           False     0              33
#
# [1490700 rows x 5 columns]

# %%
df1 = data.copy()

# %%
df2 = df1[df1["is_liar"] == True][df1.is_blacklisted == True][["lieClusterSize", "is_blacklisted"]]
df2b = df1[df1["is_liar"]  == True][["lieClusterSize"]]
# Out:
# /home/sabrina/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#          lieClusterSize  is_blacklisted
# 24                    5            True
# 25                    5            True
# 26                    5            True
# 27                    5            True
# 28                    5            True
# 29                    5            True
# 30                    5            True
# 31                    5            True
# 32                    5            True
# 33                    5            True
# 34                    5            True
# 35                    5            True
# 36                    5            True
# 37                    5            True
# 38                    5            True
# 39                    5            True
# 40                    5            True
# 41                    5            True
# 42                    5            True
# 43                    5            True
# 44                    5            True
# 45                    5            True
# 46                    5            True
# 47                    5            True
# 48                    5            True
# 49                    5            True
# 50                    5            True
# 51                    5            True
# 52                    5            True
# 53                    5            True
# ...                 ...             ...
# 1490669              33            True
# 1490670              33            True
# 1490671              33            True
# 1490672              33            True
# 1490673              33            True
# 1490674              33            True
# 1490675              33            True
# 1490676              33            True
# 1490677              33            True
# 1490678              33            True
# 1490679              33            True
# 1490680              33            True
# 1490681              33            True
# 1490682              33            True
# 1490683              33            True
# 1490684              33            True
# 1490685              33            True
# 1490686              33            True
# 1490687              33            True
# 1490688              33            True
# 1490689              33            True
# 1490690              33            True
# 1490691              33            True
# 1490692              33            True
# 1490693              33            True
# 1490694              33            True
# 1490695              33            True
# 1490696              33            True
# 1490697              33            True
# 1490698              33            True
#
# [1427091 rows x 2 columns]

# %%
df2["count"] = 1
df2b["total"] = 1

# %%
df3 = df2.groupby(["lieClusterSize", "is_blacklisted"]).sum().reset_index()
df3b = df2b.groupby(["lieClusterSize"]).sum().reset_index()

# %%
df3b
# Out:
#    lieClusterSize   total
# 0               5   48500
# 1              10   94500
# 2              15  138000
# 3              20  179000
# 4              25  217500
# 5              27  232200
# 6              30  253500
# 7              33  273900

# %%
df3
# Out:
#    lieClusterSize  is_blacklisted   count
# 0               5            True   48500
# 1              10            True   94500
# 2              15            True  138000
# 3              20            True  179000
# 4              25            True  217500
# 5              27            True  232200
# 6              30            True  253500
# 7              33            True  263891

# %%
df4 = df3.copy()

# %%
df4["proportion"] = df3["count"]/df3b["total"]

# %%
df4
# Out:
#    lieClusterSize  is_blacklisted   count  proportion
# 0               5            True   48500    1.000000
# 1              10            True   94500    1.000000
# 2              15            True  138000    1.000000
# 3              20            True  179000    1.000000
# 4              25            True  217500    1.000000
# 5              27            True  232200    1.000000
# 6              30            True  253500    1.000000
# 7              33            True  263891    0.963457

# %%
df5 = df4[["lieClusterSize", "proportion"]]

# %%
fig, ax = plt.subplots(figsize=(20, 10))
df5.plot.bar(
    stacked=True, ax=ax, x="lieClusterSize",fontsize=20)

ax.set_ylabel("Proportion of liars blacklisted",fontsize=25)
ax.set_xlabel("Number of liars in network",fontsize=25)
plt.title("Proportion of liars blacklisted for variable liar number", fontsize=30)
plt.legend(bbox_to_anchor=(0.15, 0.15), loc=1, borderaxespad=0., fontsize=15, title="Liar caught", 
           title_fontsize="20")

# %%
fig.savefig('graphs/'+filename+'.png')
