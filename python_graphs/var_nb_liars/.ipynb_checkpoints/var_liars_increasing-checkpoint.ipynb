# %% [markdown]
# # Graph for number of blacklisted liars when lies are fixed and number of liars increasing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#configs
lowerBoundLies = 1000  #lower bound on difference between true latency and lie told about it
upperBoundLies = 50000 #upper bound on difference between true latency and lie told about it
nbNodes = 100
maxNbLiars = 33
#lieClusterSizes = [5, 10, 20, 33]
nbLiarCombinations = 100 #nb different combinations of liars chosen throughout test
randomLiars = False      #whether the liars are chosen randomly or within same cluster
withSuspects = True     #activate enhanced blacklisting

random = "random_liars"
if not randomLiars:
    random = "clustered_liars"

filename = "test_" + str(nbNodes) + "_nodes_up_to_" + \
    str(maxNbLiars) + "_liars" +\
    "_var_liars_distance_" + str(upperBoundLies) +\
    "_" + random +\
    "_" + str(nbLiarCombinations) + "_combinations"

if withSuspects:
    filename += "_with_suspects"

# %%
data= pd.read_csv("data/"+filename+".csv")

# %%
data
# Out:
#         node  is_liar  is_blacklisted    lie  lieClusterSize
# 0         N0    False           False      0               5
# 1         N1    False           False      0               5
# 2         N2    False           False      0               5
# 3         N3    False           False      0               5
# 4         N4    False           False      0               5
# 5         N5    False           False      0               5
# 6         N6    False           False      0               5
# 7         N8     True            True   9926               5
# 8         N8     True            True  18493               5
# 9         N8     True            True   7620               5
# 10        N8     True            True  16948               5
# 11        N8     True            True  41450               5
# 12        N8     True            True  49948               5
# 13        N8     True            True  45943               5
# 14        N8     True            True   1896               5
# 15        N8     True            True  14358               5
# 16        N8     True            True  39289               5
# 17        N8     True            True   4627               5
# 18        N8     True            True  43343               5
# 19        N8     True            True  43057               5
# 20        N8     True            True  14534               5
# 21        N8     True            True   3830               5
# 22        N8     True            True  16933               5
# 23        N8     True            True  28151               5
# 24        N8     True            True  12527               5
# 25        N8     True            True  24623               5
# 26        N8     True            True   2738               5
# 27        N8     True            True  27986               5
# 28        N8     True            True  19959               5
# 29        N8     True            True  15937               5
# ...      ...      ...             ...    ...             ...
# 1490670  N98     True            True   1506              33
# 1490671  N98     True            True  46275              33
# 1490672  N98     True            True   6209              33
# 1490673  N98     True            True  16078              33
# 1490674  N98     True            True  24278              33
# 1490675  N98     True            True  43702              33
# 1490676  N98     True            True  39528              33
# 1490677  N98     True            True  25965              33
# 1490678  N98     True            True  32983              33
# 1490679  N98     True            True  15944              33
# 1490680  N98     True            True  22517              33
# 1490681  N98     True            True  40039              33
# 1490682  N98     True            True  35493              33
# 1490683  N98     True            True  31406              33
# 1490684  N98     True            True  35515              33
# 1490685  N98     True            True   6995              33
# 1490686  N98     True            True  27131              33
# 1490687  N98     True            True  49500              33
# 1490688  N98     True            True  10557              33
# 1490689  N98     True            True   9911              33
# 1490690  N98     True            True  17498              33
# 1490691  N98     True            True  36015              33
# 1490692  N98     True            True  20934              33
# 1490693  N98     True            True  28474              33
# 1490694  N98     True            True  36440              33
# 1490695  N98     True            True  21688              33
# 1490696  N98     True            True   1642              33
# 1490697  N98     True            True  32236              33
# 1490698  N98     True            True  41831              33
# 1490699  N99    False           False      0              33
#
# [1490700 rows x 5 columns]

# %%
data["grouped"] = list(zip(data.is_liar, data.is_blacklisted))
grouped_data = data[["node", "grouped", "lieClusterSize"]]

# %%
grouped_data
# Out:
#         node         grouped  lieClusterSize
# 0         N0  (False, False)               5
# 1         N1  (False, False)               5
# 2         N2  (False, False)               5
# 3         N3  (False, False)               5
# 4         N4  (False, False)               5
# 5         N5  (False, False)               5
# 6         N6  (False, False)               5
# 7         N8    (True, True)               5
# 8         N8    (True, True)               5
# 9         N8    (True, True)               5
# 10        N8    (True, True)               5
# 11        N8    (True, True)               5
# 12        N8    (True, True)               5
# 13        N8    (True, True)               5
# 14        N8    (True, True)               5
# 15        N8    (True, True)               5
# 16        N8    (True, True)               5
# 17        N8    (True, True)               5
# 18        N8    (True, True)               5
# 19        N8    (True, True)               5
# 20        N8    (True, True)               5
# 21        N8    (True, True)               5
# 22        N8    (True, True)               5
# 23        N8    (True, True)               5
# 24        N8    (True, True)               5
# 25        N8    (True, True)               5
# 26        N8    (True, True)               5
# 27        N8    (True, True)               5
# 28        N8    (True, True)               5
# 29        N8    (True, True)               5
# ...      ...             ...             ...
# 1490670  N98    (True, True)              33
# 1490671  N98    (True, True)              33
# 1490672  N98    (True, True)              33
# 1490673  N98    (True, True)              33
# 1490674  N98    (True, True)              33
# 1490675  N98    (True, True)              33
# 1490676  N98    (True, True)              33
# 1490677  N98    (True, True)              33
# 1490678  N98    (True, True)              33
# 1490679  N98    (True, True)              33
# 1490680  N98    (True, True)              33
# 1490681  N98    (True, True)              33
# 1490682  N98    (True, True)              33
# 1490683  N98    (True, True)              33
# 1490684  N98    (True, True)              33
# 1490685  N98    (True, True)              33
# 1490686  N98    (True, True)              33
# 1490687  N98    (True, True)              33
# 1490688  N98    (True, True)              33
# 1490689  N98    (True, True)              33
# 1490690  N98    (True, True)              33
# 1490691  N98    (True, True)              33
# 1490692  N98    (True, True)              33
# 1490693  N98    (True, True)              33
# 1490694  N98    (True, True)              33
# 1490695  N98    (True, True)              33
# 1490696  N98    (True, True)              33
# 1490697  N98    (True, True)              33
# 1490698  N98    (True, True)              33
# 1490699  N99  (False, False)              33
#
# [1490700 rows x 3 columns]

# %%
grouped_by_node = grouped_data.groupby(["node", "lieClusterSize"]).agg(lambda x: set(x.values.tolist()))

# %%
grouped_by_node["nb_situations"] = grouped_by_node['grouped'].map(lambda x: len(x))

# %%
grouped_by_node
# Out:
#                                                            grouped  \
# node lieClusterSize
# N0   5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      15                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      25                             {(False, False), (True, True)}
#      27                             {(False, False), (True, True)}
#      30                             {(False, False), (True, True)}
#      33              {(True, False), (False, False), (True, True)}
# N1   5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      15                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      25                             {(False, False), (True, True)}
#      27              {(True, False), (False, False), (True, True)}
#      30              {(True, False), (False, False), (True, True)}
#      33              {(True, False), (False, False), (True, True)}
# N10  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      15                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      25                             {(False, False), (True, True)}
#      27                             {(False, False), (True, True)}
#      30              {(True, False), (False, False), (True, True)}
#      33              {(True, False), (False, False), (True, True)}
# N11  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      15                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      25                             {(False, False), (True, True)}
#      27                             {(False, False), (True, True)}
# ...                                                            ...
# N96  15                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      25                             {(False, False), (True, True)}
#      27                             {(False, False), (True, True)}
#      30                             {(False, False), (True, True)}
#      33                             {(False, False), (True, True)}
# N97  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      15                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      25                             {(False, False), (True, True)}
#      27                             {(False, False), (True, True)}
#      30                             {(False, False), (True, True)}
#      33                             {(False, False), (True, True)}
# N98  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      15                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      25                             {(False, False), (True, True)}
#      27                             {(False, False), (True, True)}
#      30                             {(False, False), (True, True)}
#      33                             {(False, False), (True, True)}
# N99  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      15                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      25                             {(False, False), (True, True)}
#      27                             {(False, False), (True, True)}
#      30                             {(False, False), (True, True)}
#      33                             {(False, False), (True, True)}
#
#                      nb_situations
# node lieClusterSize
# N0   5                           2
#      10                          2
#      15                          2
#      20                          2
#      25                          2
#      27                          2
#      30                          2
#      33                          3
# N1   5                           2
#      10                          2
#      15                          2
#      20                          2
#      25                          2
#      27                          3
#      30                          3
#      33                          3
# N10  5                           2
#      10                          2
#      15                          2
#      20                          2
#      25                          2
#      27                          2
#      30                          3
#      33                          3
# N11  5                           2
#      10                          2
#      15                          2
#      20                          2
#      25                          2
#      27                          2
# ...                            ...
# N96  15                          2
#      20                          2
#      25                          2
#      27                          2
#      30                          2
#      33                          2
# N97  5                           2
#      10                          2
#      15                          2
#      20                          2
#      25                          2
#      27                          2
#      30                          2
#      33                          2
# N98  5                           2
#      10                          2
#      15                          2
#      20                          2
#      25                          2
#      27                          2
#      30                          2
#      33                          2
# N99  5                           2
#      10                          2
#      15                          2
#      20                          2
#      25                          2
#      27                          2
#      30                          2
#      33                          2
#
# [800 rows x 2 columns]

# %%
data[["node", "lieClusterSize","is_liar", "is_blacklisted"]]\
.groupby(["is_liar", "is_blacklisted", "lieClusterSize"]).count()
# Out:
#                                          node
# is_liar is_blacklisted lieClusterSize
# False   False          5                 6700
#                        10                6700
#                        15                6700
#                        20                6700
#                        25                6700
#                        27                6700
#                        30                6700
#                        33                6700
# True    False          27                1259
#                        30               31354
#                        33              121689
#         True           5                48500
#                        10               94500
#                        15              138000
#                        20              179000
#                        25              217500
#                        27              230941
#                        30              222146
#                        33              152211

# %%
lies = data[["node","lieClusterSize","is_blacklisted"]][data["lie"] > 0][["lieClusterSize","is_blacklisted"]]

# %%
lies
# Out:
#          lieClusterSize  is_blacklisted
# 7                     5            True
# 8                     5            True
# 9                     5            True
# 10                    5            True
# 11                    5            True
# 12                    5            True
# 13                    5            True
# 14                    5            True
# 15                    5            True
# 16                    5            True
# 17                    5            True
# 18                    5            True
# 19                    5            True
# 20                    5            True
# 21                    5            True
# 22                    5            True
# 23                    5            True
# 24                    5            True
# 25                    5            True
# 26                    5            True
# 27                    5            True
# 28                    5            True
# 29                    5            True
# 30                    5            True
# 31                    5            True
# 32                    5            True
# 33                    5            True
# 34                    5            True
# 35                    5            True
# 36                    5            True
# ...                 ...             ...
# 1490669              33            True
# 1490670              33            True
# 1490671              33            True
# 1490672              33            True
# 1490673              33            True
# 1490674              33            True
# 1490675              33            True
# 1490676              33            True
# 1490677              33            True
# 1490678              33            True
# 1490679              33            True
# 1490680              33            True
# 1490681              33            True
# 1490682              33            True
# 1490683              33            True
# 1490684              33            True
# 1490685              33            True
# 1490686              33            True
# 1490687              33            True
# 1490688              33            True
# 1490689              33            True
# 1490690              33            True
# 1490691              33            True
# 1490692              33            True
# 1490693              33            True
# 1490694              33            True
# 1490695              33            True
# 1490696              33            True
# 1490697              33            True
# 1490698              33            True
#
# [1437100 rows x 2 columns]

# %%
lies.groupby("lieClusterSize").agg(lambda x: set(x.values.tolist())).reset_index()
# Out:
#    lieClusterSize is_blacklisted
# 0               5         {True}
# 1              10         {True}
# 2              15         {True}
# 3              20         {True}
# 4              25         {True}
# 5              27  {False, True}
# 6              30  {False, True}
# 7              33  {False, True}

# %%
bl_by_lie = lies.groupby(['lieClusterSize', 'is_blacklisted']).size().unstack(fill_value=0).reset_index()

# %%
proportions = bl_by_lie[["lieClusterSize", True, False]]\
.groupby("lieClusterSize").sum().reset_index()

# %%
proportions[True] = proportions[True]/100

# %%
proportions
# Out:
# is_blacklisted  lieClusterSize     True   False
# 0                            5   485.00       0
# 1                           10   945.00       0
# 2                           15  1380.00       0
# 3                           20  1790.00       0
# 4                           25  2175.00       0
# 5                           27  2309.41    1259
# 6                           30  2221.46   31354
# 7                           33  1522.11  121689

# %%
fig, ax = plt.subplots(figsize=(20, 10))
proportions.plot.bar(
    stacked=True, ax=ax, x="lieClusterSize", 
    title="Proportion of liars blacklisted given the number of selected clustered liars in a network, "+\
    "with suspect blacklisted")

ax.set_ylabel("Number of liars blacklisted")
ax.set_xlabel("Number of liars in network")
# Out:
# Text(0.5, 0, 'Number of liars in network')

# %%
fig.savefig('graphs/'+filename+'.png')
