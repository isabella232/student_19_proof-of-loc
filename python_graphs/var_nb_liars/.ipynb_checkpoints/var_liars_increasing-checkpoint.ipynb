# %% [markdown]
# # Graph for number of blacklisted liars when lies are fixed and number of liars increasing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#configs
lowerBoundLies = 1000  #lower bound on difference between true latency and lie told about it
upperBoundLies = 10000 #upper bound on difference between true latency and lie told about it
nbNodes = 100
maxNbLiars = 33
lieClusterSizes = [5, 10, 15, 20, 25, 27, 30, 33]
nbLiarCombinations = 100 #nb different combinations of liars chosen throughout test
randomLiars = True      #whether the liars are chosen randomly or within same cluster
withSuspects = True     #activate enhanced blacklisting

random = "random_liars"
if not randomLiars:
    random = "clustered_liars"

filename = "test_" + str(nbNodes) + "_nodes_up_to_" + \
    str(maxNbLiars) + "_liars" +\
    "_var_liars_distance_" + str(upperBoundLies) +\
    "_" + random +\
    "_" + str(nbLiarCombinations) + "_combinations"

if withSuspects:
    filename += "_with_suspects"

# %%
data= pd.read_csv("data/"+filename+".csv")

# %%
data
# Out:
#         node  is_liar  is_blacklisted   lie  lieClusterSize
# 0         N0    False           False     0               5
# 1         N1    False           False     0               5
# 2         N2    False           False     0               5
# 3         N3     True            True  6049               5
# 4         N3     True            True  3927               5
# 5         N3     True            True  6330               5
# 6         N3     True            True  8271               5
# 7         N3     True            True  3265               5
# 8         N3     True            True  3045               5
# 9         N3     True            True  6524               5
# 10        N3     True            True  8592               5
# 11        N3     True            True  4461               5
# 12        N3     True            True  6732               5
# 13        N3     True            True  7336               5
# 14        N3     True            True  7288               5
# 15        N3     True            True  2252               5
# 16        N3     True            True  5392               5
# 17        N3     True            True  6829               5
# 18        N3     True            True  3630               5
# 19        N3     True            True  7317               5
# 20        N3     True            True  2287               5
# 21        N3     True            True  7691               5
# 22        N3     True            True  6457               5
# 23        N3     True            True  2945               5
# 24        N3     True            True  6172               5
# 25        N3     True            True  8283               5
# 26        N3     True            True  5379               5
# 27        N3     True            True  6757               5
# 28        N3     True            True  7009               5
# 29        N3     True            True  2323               5
# ...      ...      ...             ...   ...             ...
# 1490670  N95     True            True  8879              33
# 1490671  N95     True            True  1892              33
# 1490672  N95     True            True  1859              33
# 1490673  N95     True            True  9172              33
# 1490674  N95     True            True  6260              33
# 1490675  N95     True            True  5786              33
# 1490676  N95     True            True  2968              33
# 1490677  N95     True            True  5436              33
# 1490678  N95     True            True  1163              33
# 1490679  N95     True            True  5093              33
# 1490680  N95     True            True  2261              33
# 1490681  N95     True            True  1767              33
# 1490682  N95     True            True  5083              33
# 1490683  N95     True            True  3270              33
# 1490684  N95     True            True  1589              33
# 1490685  N95     True            True  3827              33
# 1490686  N95     True            True  5808              33
# 1490687  N95     True            True  2368              33
# 1490688  N95     True            True  3966              33
# 1490689  N95     True            True  3314              33
# 1490690  N95     True            True  9373              33
# 1490691  N95     True            True  3517              33
# 1490692  N95     True            True  7564              33
# 1490693  N95     True            True  4002              33
# 1490694  N95     True            True  1009              33
# 1490695  N95     True            True  7891              33
# 1490696  N96    False           False     0              33
# 1490697  N97    False           False     0              33
# 1490698  N98    False           False     0              33
# 1490699  N99    False           False     0              33
#
# [1490700 rows x 5 columns]

# %%
df1 = data.copy()

# %%
df2 = df1[df1["is_liar"] == True][df1.is_blacklisted == True][["lieClusterSize", "is_blacklisted"]]
df2b = df1[df1["is_liar"]  == True][["lieClusterSize"]]
# Out:
# /home/sabrina/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#          lieClusterSize  is_blacklisted
# 3                     5            True
# 4                     5            True
# 5                     5            True
# 6                     5            True
# 7                     5            True
# 8                     5            True
# 9                     5            True
# 10                    5            True
# 11                    5            True
# 12                    5            True
# 13                    5            True
# 14                    5            True
# 15                    5            True
# 16                    5            True
# 17                    5            True
# 18                    5            True
# 19                    5            True
# 20                    5            True
# 21                    5            True
# 22                    5            True
# 23                    5            True
# 24                    5            True
# 25                    5            True
# 26                    5            True
# 27                    5            True
# 28                    5            True
# 29                    5            True
# 30                    5            True
# 31                    5            True
# 32                    5            True
# ...                 ...             ...
# 1490666              33            True
# 1490667              33            True
# 1490668              33            True
# 1490669              33            True
# 1490670              33            True
# 1490671              33            True
# 1490672              33            True
# 1490673              33            True
# 1490674              33            True
# 1490675              33            True
# 1490676              33            True
# 1490677              33            True
# 1490678              33            True
# 1490679              33            True
# 1490680              33            True
# 1490681              33            True
# 1490682              33            True
# 1490683              33            True
# 1490684              33            True
# 1490685              33            True
# 1490686              33            True
# 1490687              33            True
# 1490688              33            True
# 1490689              33            True
# 1490690              33            True
# 1490691              33            True
# 1490692              33            True
# 1490693              33            True
# 1490694              33            True
# 1490695              33            True
#
# [1436470 rows x 2 columns]

# %%
df2["count"] = 1
df2b["total"] = 1

# %%
df3 = df2.groupby(["lieClusterSize", "is_blacklisted"]).sum().reset_index()
df3b = df2b.groupby(["lieClusterSize"]).sum().reset_index()

# %%
df3b
# Out:
#    lieClusterSize   total
# 0               5   48500
# 1              10   94500
# 2              15  138000
# 3              20  179000
# 4              25  217500
# 5              27  232200
# 6              30  253500
# 7              33  273900

# %%
df3
# Out:
#    lieClusterSize  is_blacklisted   count
# 0               5            True   48500
# 1              10            True   94500
# 2              15            True  137370
# 3              20            True  179000
# 4              25            True  217500
# 5              27            True  232200
# 6              30            True  253500
# 7              33            True  273900

# %%
df4 = df3.copy()

# %%
df4["proportion"] = df3["count"]/df3b["total"]

# %%
df4
# Out:
#    lieClusterSize  is_blacklisted   count  proportion
# 0               5            True   48500    1.000000
# 1              10            True   94500    1.000000
# 2              15            True  137370    0.995435
# 3              20            True  179000    1.000000
# 4              25            True  217500    1.000000
# 5              27            True  232200    1.000000
# 6              30            True  253500    1.000000
# 7              33            True  273900    1.000000

# %%
df5 = df4[["lieClusterSize", "proportion"]]

# %%
df5
# Out:
#    lieClusterSize  proportion
# 0               5    1.000000
# 1              10    1.000000
# 2              15    0.995435
# 3              20    1.000000
# 4              25    1.000000
# 5              27    1.000000
# 6              30    1.000000
# 7              33    1.000000

# %%
zero_ticks = []
for tick in lieClusterSizes:
    if tick not in list(df5["lieClusterSize"]):
        zero_ticks.append([tick, 0.0])
df6 = pd.DataFrame(zero_ticks, columns=df5.columns)

# %%
df6
# Out:
# Empty DataFrame
# Columns: [lieClusterSize, proportion]
# Index: []

# %%
df7 = df5.append(df6)

# %%
df7
# Out:
#   lieClusterSize  proportion
# 0              5    1.000000
# 1             10    1.000000
# 2             15    0.995435
# 3             20    1.000000
# 4             25    1.000000
# 5             27    1.000000
# 6             30    1.000000
# 7             33    1.000000

# %%
fig, ax = plt.subplots(figsize=(20, 7))
df7.plot.bar(
    stacked=True, ax=ax, x="lieClusterSize",fontsize=20)

ax.set_xticklabels(lieClusterSizes)
ax.set_yticklabels([0, 0.2, 0.4, 0.6, 0.8, 1])
ax.set_ylabel("Proportion of liars blacklisted",fontsize=25)
ax.set_xlabel("Number of liars in network",fontsize=25)
plt.title("Proportion of liars blacklisted for variable liar number", fontsize=30)
plt.legend(bbox_to_anchor=(0.15, 0.15), loc=1, borderaxespad=0., fontsize=15, title="Liar caught", 
           title_fontsize="20")

# %%
fig.savefig('graphs/'+filename+'.png')
