# %% [markdown]
# # Graph for number of blacklisted liars when lies are fixed and number of liars increasing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#configs
lowerBoundLies = 1000  #lower bound on difference between true latency and lie told about it
upperBoundLies = 50000 #upper bound on difference between true latency and lie told about it
nbNodes = 100
maxNbLiars = 33
lieClusterSizes = [5, 10, 20, 33]
nbLiarCombinations = 100 #nb different combinations of liars chosen throughout test
randomLiars = False      #whether the liars are chosen randomly or within same cluster
withSuspects = True     #activate enhanced blacklisting

random = "random_liars"
if not randomLiars:
    random = "clustered_liars"

filename = "test_" + str(nbNodes) + "_nodes_up_to_" + \
    str(maxNbLiars) + "_liars" +\
    "_var_liars_distance_" + str(upperBoundLies) +\
    "_" + random +\
    "_" + str(nbLiarCombinations) + "_combinations"

if withSuspects:
    filename += "_with_suspects"

# %%
data= pd.read_csv("data/"+filename+".csv")

# %%
data
# Out:
#        node  is_liar  is_blacklisted    lie  lieClusterSize
# 0        N0    False           False      0               5
# 1        N1    False           False      0               5
# 2        N2    False           False      0               5
# 3        N4    False           False      0               5
# 4        N6    False           False      0               5
# 5        N7    False           False      0               5
# 6       N11    False           False      0               5
# 7       N13    False           False      0               5
# 8       N15    False           False      0               5
# 9       N17    False           False      0               5
# 10      N18    False           False      0               5
# 11      N19    False           False      0               5
# 12      N20    False           False      0               5
# 13      N21     True            True  36943               5
# 14      N21     True            True  21424               5
# 15      N21     True            True  36295               5
# 16      N21     True            True  37820               5
# 17      N21     True            True  46878               5
# 18      N21     True            True  18862               5
# 19      N21     True            True  19576               5
# 20      N21     True            True  11010               5
# 21      N21     True            True   4885               5
# 22      N21     True            True  37336               5
# 23      N21     True            True   8982               5
# 24      N21     True            True  25962               5
# 25      N21     True            True  21704               5
# 26      N21     True            True  14091               5
# 27      N21     True            True  32772               5
# 28      N21     True            True  33343               5
# 29      N21     True            True  15433               5
# ...     ...      ...             ...    ...             ...
# 622670  N98     True           False  49839              33
# 622671  N98     True           False  33259              33
# 622672  N98     True           False  10534              33
# 622673  N98     True           False  38176              33
# 622674  N98     True           False  48752              33
# 622675  N98     True           False  42618              33
# 622676  N98     True           False  27720              33
# 622677  N98     True           False  13695              33
# 622678  N98     True           False  25573              33
# 622679  N98     True           False  45213              33
# 622680  N98     True           False  25818              33
# 622681  N98     True           False  49923              33
# 622682  N98     True           False  30160              33
# 622683  N98     True           False  16767              33
# 622684  N98     True           False  14089              33
# 622685  N98     True           False  44022              33
# 622686  N98     True           False  11760              33
# 622687  N98     True           False  49402              33
# 622688  N98     True           False   4725              33
# 622689  N98     True           False  48451              33
# 622690  N98     True           False  26608              33
# 622691  N98     True           False   5254              33
# 622692  N98     True           False  15737              33
# 622693  N98     True           False  22221              33
# 622694  N98     True           False  22453              33
# 622695  N98     True           False  37059              33
# 622696  N98     True           False  48556              33
# 622697  N98     True           False  45878              33
# 622698  N98     True           False  36922              33
# 622699  N99    False           False      0              33
#
# [622700 rows x 5 columns]

# %%
data["grouped"] = list(zip(data.is_liar, data.is_blacklisted))
grouped_data = data[["node", "grouped", "lieClusterSize"]]

# %%
grouped_data
# Out:
#        node         grouped  lieClusterSize
# 0        N0  (False, False)               5
# 1        N1  (False, False)               5
# 2        N2  (False, False)               5
# 3        N4  (False, False)               5
# 4        N6  (False, False)               5
# 5        N7  (False, False)               5
# 6       N11  (False, False)               5
# 7       N13  (False, False)               5
# 8       N15  (False, False)               5
# 9       N17  (False, False)               5
# 10      N18  (False, False)               5
# 11      N19  (False, False)               5
# 12      N20  (False, False)               5
# 13      N21    (True, True)               5
# 14      N21    (True, True)               5
# 15      N21    (True, True)               5
# 16      N21    (True, True)               5
# 17      N21    (True, True)               5
# 18      N21    (True, True)               5
# 19      N21    (True, True)               5
# 20      N21    (True, True)               5
# 21      N21    (True, True)               5
# 22      N21    (True, True)               5
# 23      N21    (True, True)               5
# 24      N21    (True, True)               5
# 25      N21    (True, True)               5
# 26      N21    (True, True)               5
# 27      N21    (True, True)               5
# 28      N21    (True, True)               5
# 29      N21    (True, True)               5
# ...     ...             ...             ...
# 622670  N98   (True, False)              33
# 622671  N98   (True, False)              33
# 622672  N98   (True, False)              33
# 622673  N98   (True, False)              33
# 622674  N98   (True, False)              33
# 622675  N98   (True, False)              33
# 622676  N98   (True, False)              33
# 622677  N98   (True, False)              33
# 622678  N98   (True, False)              33
# 622679  N98   (True, False)              33
# 622680  N98   (True, False)              33
# 622681  N98   (True, False)              33
# 622682  N98   (True, False)              33
# 622683  N98   (True, False)              33
# 622684  N98   (True, False)              33
# 622685  N98   (True, False)              33
# 622686  N98   (True, False)              33
# 622687  N98   (True, False)              33
# 622688  N98   (True, False)              33
# 622689  N98   (True, False)              33
# 622690  N98   (True, False)              33
# 622691  N98   (True, False)              33
# 622692  N98   (True, False)              33
# 622693  N98   (True, False)              33
# 622694  N98   (True, False)              33
# 622695  N98   (True, False)              33
# 622696  N98   (True, False)              33
# 622697  N98   (True, False)              33
# 622698  N98   (True, False)              33
# 622699  N99  (False, False)              33
#
# [622700 rows x 3 columns]

# %%
grouped_by_node = grouped_data.groupby(["node", "lieClusterSize"]).agg(lambda x: set(x.values.tolist()))

# %%
grouped_by_node["nb_situations"] = grouped_by_node['grouped'].map(lambda x: len(x))

# %%
grouped_by_node
# Out:
#                                                            grouped  \
# node lieClusterSize
# N0   5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      33              {(True, False), (False, False), (True, True)}
# N1   5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      33              {(True, False), (False, False), (True, True)}
# N10  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      33              {(True, False), (False, False), (True, True)}
# N11  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      33              {(True, False), (False, False), (True, True)}
# N12  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      33              {(True, False), (False, False), (True, True)}
# N13  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      33              {(True, False), (False, False), (True, True)}
# N14  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      33                             {(False, False), (True, True)}
# N15  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
# ...                                                            ...
# N92  20                             {(False, False), (True, True)}
#      33                             {(False, False), (True, True)}
# N93  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      33                             {(False, False), (True, True)}
# N94  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      33                             {(False, False), (True, True)}
# N95  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      33                             {(False, False), (True, True)}
# N96  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      33                             {(False, False), (True, True)}
# N97  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      33              {(True, False), (False, False), (True, True)}
# N98  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      33              {(True, False), (False, False), (True, True)}
# N99  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
#      33              {(True, False), (False, False), (True, True)}
#
#                      nb_situations
# node lieClusterSize
# N0   5                           2
#      10                          2
#      20                          2
#      33                          3
# N1   5                           2
#      10                          2
#      20                          2
#      33                          3
# N10  5                           2
#      10                          2
#      20                          2
#      33                          3
# N11  5                           2
#      10                          2
#      20                          2
#      33                          3
# N12  5                           2
#      10                          2
#      20                          2
#      33                          3
# N13  5                           2
#      10                          2
#      20                          2
#      33                          3
# N14  5                           2
#      10                          2
#      20                          2
#      33                          2
# N15  5                           2
#      10                          2
# ...                            ...
# N92  20                          2
#      33                          2
# N93  5                           2
#      10                          2
#      20                          2
#      33                          2
# N94  5                           2
#      10                          2
#      20                          2
#      33                          2
# N95  5                           2
#      10                          2
#      20                          2
#      33                          2
# N96  5                           2
#      10                          2
#      20                          2
#      33                          2
# N97  5                           2
#      10                          2
#      20                          2
#      33                          3
# N98  5                           2
#      10                          2
#      20                          2
#      33                          3
# N99  5                           2
#      10                          2
#      20                          2
#      33                          3
#
# [400 rows x 2 columns]

# %%
data[["node", "lieClusterSize","is_liar", "is_blacklisted"]]\
.groupby(["is_liar", "is_blacklisted", "lieClusterSize"]).count()
# Out:
#                                          node
# is_liar is_blacklisted lieClusterSize
# False   False          5                 6700
#                        10                6700
#                        20                6700
#                        33                6700
# True    False          33               41191
#         True           5                48500
#                        10               94500
#                        20              179000
#                        33              232709

# %%
lies = data[["node","lieClusterSize","is_blacklisted"]][data["lie"] > 0][["lieClusterSize","is_blacklisted"]]

# %%
lies
# Out:
#         lieClusterSize  is_blacklisted
# 13                   5            True
# 14                   5            True
# 15                   5            True
# 16                   5            True
# 17                   5            True
# 18                   5            True
# 19                   5            True
# 20                   5            True
# 21                   5            True
# 22                   5            True
# 23                   5            True
# 24                   5            True
# 25                   5            True
# 26                   5            True
# 27                   5            True
# 28                   5            True
# 29                   5            True
# 30                   5            True
# 31                   5            True
# 32                   5            True
# 33                   5            True
# 34                   5            True
# 35                   5            True
# 36                   5            True
# 37                   5            True
# 38                   5            True
# 39                   5            True
# 40                   5            True
# 41                   5            True
# 42                   5            True
# ...                ...             ...
# 622669              33           False
# 622670              33           False
# 622671              33           False
# 622672              33           False
# 622673              33           False
# 622674              33           False
# 622675              33           False
# 622676              33           False
# 622677              33           False
# 622678              33           False
# 622679              33           False
# 622680              33           False
# 622681              33           False
# 622682              33           False
# 622683              33           False
# 622684              33           False
# 622685              33           False
# 622686              33           False
# 622687              33           False
# 622688              33           False
# 622689              33           False
# 622690              33           False
# 622691              33           False
# 622692              33           False
# 622693              33           False
# 622694              33           False
# 622695              33           False
# 622696              33           False
# 622697              33           False
# 622698              33           False
#
# [595900 rows x 2 columns]

# %%
lies.groupby("lieClusterSize").agg(lambda x: set(x.values.tolist())).reset_index()
# Out:
#    lieClusterSize is_blacklisted
# 0               5         {True}
# 1              10         {True}
# 2              20         {True}
# 3              33  {False, True}

# %%
bl_by_lie = lies.groupby(['lieClusterSize', 'is_blacklisted']).size().unstack(fill_value=0).reset_index()

# %%
bl_by_lie
# Out:
# is_blacklisted  lieClusterSize  False    True
# 0                            5      0   48500
# 1                           10      0   94500
# 2                           20      0  179000
# 3                           33  41191  232709

# %%
fig, ax = plt.subplots(figsize=(20, 10))
bl_by_lie[["lieClusterSize", True, False]]\
.groupby("lieClusterSize").sum().reset_index().plot.bar(
    stacked=True, ax=ax, x="lieClusterSize", 
    title="Proportion of liars blacklisted given the number of selected clustered liars in a network, "+\
    "with suspect blacklisted")

ax.set_ylabel("Number of liars blacklisted")
ax.set_xlabel("Number of liars in network")
# Out:
# Text(0.5, 0, 'Number of liars in network')

# %%
fig.savefig('graphs/'+filename+'.png')
