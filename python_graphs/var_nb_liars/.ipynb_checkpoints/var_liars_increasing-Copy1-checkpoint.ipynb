# %% [markdown]
# # Graph for number of blacklisted liars when lies are fixed and number of liars increasing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#configs
lowerBoundLies = 1000  #lower bound on difference between true latency and lie told about it
upperBoundLies = 50000 #upper bound on difference between true latency and lie told about it
nbNodes = 100
maxNbLiars = 33
#lieClusterSizes = [5, 10, 20, 33]
nbLiarCombinations = 100 #nb different combinations of liars chosen throughout test
randomLiars = True      #whether the liars are chosen randomly or within same cluster
withSuspects = True     #activate enhanced blacklisting

random = "random_liars"
if not randomLiars:
    random = "clustered_liars"

filename = "test_" + str(nbNodes) + "_nodes_up_to_" + \
    str(maxNbLiars) + "_liars" +\
    "_var_liars_distance_" + str(upperBoundLies) +\
    "_" + random +\
    "_" + str(nbLiarCombinations) + "_combinations"

if withSuspects:
    filename += "_with_suspects"

# %%
data= pd.read_csv("data/"+filename+".csv")

# %%
data
# Out:
#         node  is_liar  is_blacklisted    lie  lieClusterSize
# 0         N0    False           False      0               5
# 1         N2    False           False      0               5
# 2         N3    False           False      0               5
# 3         N4    False           False      0               5
# 4         N6    False           False      0               5
# 5         N8    False           False      0               5
# 6         N9    False           False      0               5
# 7        N11    False           False      0               5
# 8        N12    False           False      0               5
# 9        N13    False           False      0               5
# 10       N14    False           False      0               5
# 11       N16    False           False      0               5
# 12       N17    False           False      0               5
# 13       N18    False           False      0               5
# 14       N19    False           False      0               5
# 15       N20    False           False      0               5
# 16       N22    False           False      0               5
# 17       N23    False           False      0               5
# 18       N24    False           False      0               5
# 19       N25    False           False      0               5
# 20       N26     True            True   5020               5
# 21       N26     True            True  38559               5
# 22       N26     True            True  43184               5
# 23       N26     True            True  41820               5
# 24       N26     True            True   4175               5
# 25       N26     True            True  24094               5
# 26       N26     True            True  10686               5
# 27       N26     True            True   3477               5
# 28       N26     True            True  17029               5
# 29       N26     True            True  10624               5
# ...      ...      ...             ...    ...             ...
# 1490670  N98     True           False  12849              33
# 1490671  N98     True           False  27409              33
# 1490672  N98     True           False  28298              33
# 1490673  N98     True           False  31684              33
# 1490674  N98     True           False  40512              33
# 1490675  N98     True           False  33023              33
# 1490676  N98     True           False  37433              33
# 1490677  N98     True           False  40970              33
# 1490678  N98     True           False   9495              33
# 1490679  N98     True           False  20899              33
# 1490680  N98     True           False  32577              33
# 1490681  N98     True           False  44761              33
# 1490682  N98     True           False  20807              33
# 1490683  N98     True           False  14920              33
# 1490684  N98     True           False  34208              33
# 1490685  N98     True           False  31643              33
# 1490686  N98     True           False  31104              33
# 1490687  N98     True           False  16268              33
# 1490688  N98     True           False  38612              33
# 1490689  N98     True           False  14245              33
# 1490690  N98     True           False  49774              33
# 1490691  N98     True           False  13838              33
# 1490692  N98     True           False  27872              33
# 1490693  N98     True           False  10914              33
# 1490694  N98     True           False   3417              33
# 1490695  N98     True           False  16382              33
# 1490696  N98     True           False  45783              33
# 1490697  N98     True           False  37411              33
# 1490698  N98     True           False  13155              33
# 1490699  N99    False           False      0              33
#
# [1490700 rows x 5 columns]

# %%
df1 = data.copy()

# %%
df2 = df1[df1["is_liar"] == True][df1.is_blacklisted == True][["lieClusterSize", "is_blacklisted"]]
df2b = df1[df1["is_liar"]  == True][["lieClusterSize"]]
# Out:
# /home/sabrina/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#          lieClusterSize  is_blacklisted
# 20                    5            True
# 21                    5            True
# 22                    5            True
# 23                    5            True
# 24                    5            True
# 25                    5            True
# 26                    5            True
# 27                    5            True
# 28                    5            True
# 29                    5            True
# 30                    5            True
# 31                    5            True
# 32                    5            True
# 33                    5            True
# 34                    5            True
# 35                    5            True
# 36                    5            True
# 37                    5            True
# 38                    5            True
# 39                    5            True
# 40                    5            True
# 41                    5            True
# 42                    5            True
# 43                    5            True
# 44                    5            True
# 45                    5            True
# 46                    5            True
# 47                    5            True
# 48                    5            True
# 49                    5            True
# ...                 ...             ...
# 1490601              33            True
# 1490602              33            True
# 1490603              33            True
# 1490604              33            True
# 1490605              33            True
# 1490606              33            True
# 1490607              33            True
# 1490608              33            True
# 1490609              33            True
# 1490610              33            True
# 1490611              33            True
# 1490612              33            True
# 1490613              33            True
# 1490614              33            True
# 1490615              33            True
# 1490616              33            True
# 1490617              33            True
# 1490618              33            True
# 1490619              33            True
# 1490620              33            True
# 1490621              33            True
# 1490622              33            True
# 1490623              33            True
# 1490624              33            True
# 1490625              33            True
# 1490626              33            True
# 1490627              33            True
# 1490628              33            True
# 1490629              33            True
# 1490630              33            True
#
# [1303065 rows x 2 columns]

# %%
df2["count"] = 1
df2b["total"] = 1

# %%
df3 = df2.groupby(["lieClusterSize", "is_blacklisted"]).sum().reset_index()
df3b = df2b.groupby(["lieClusterSize"]).sum().reset_index()

# %%
df3b
# Out:
#    lieClusterSize   total
# 0               5   48500
# 1              10   94500
# 2              15  138000
# 3              20  179000
# 4              25  217500
# 5              27  232200
# 6              30  253500
# 7              33  273900

# %%
df3
# Out:
#    lieClusterSize  is_blacklisted   count
# 0               5            True   48500
# 1              10            True   94500
# 2              15            True  138000
# 3              20            True  179000
# 4              25            True  217500
# 5              27            True  232112
# 6              30            True  230355
# 7              33            True  163098

# %%
df4 = df3.copy()

# %%
df4["proportion"] = df3["count"]/df3b["total"]

# %%
df4
# Out:
#    lieClusterSize  is_blacklisted   count  proportion
# 0               5            True   48500    1.000000
# 1              10            True   94500    1.000000
# 2              15            True  138000    1.000000
# 3              20            True  179000    1.000000
# 4              25            True  217500    1.000000
# 5              27            True  232112    0.999621
# 6              30            True  230355    0.908698
# 7              33            True  163098    0.595465

# %%
df5 = df4[["lieClusterSize", "proportion"]]

# %%
fig, ax = plt.subplots(figsize=(20, 10))
df5.plot.bar(
    stacked=True, ax=ax, x="lieClusterSize", 
    title="Proportion of liars blacklisted given the number of selected clustered liars in a network, "+\
    "with suspect blacklisted")

ax.set_ylabel("Proportion of liars blacklisted")
ax.set_xlabel("Number of liars in network")
# Out:
# Text(0.5, 0, 'Number of liars in network')

# %%
fig.savefig('graphs/'+filename+'.png')
