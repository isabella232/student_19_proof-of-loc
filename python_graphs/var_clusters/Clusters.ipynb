# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
nbClusters = "2"
nbLiars = "2"
filename =nbLiars + "_liar_size_imbalance_" + nbClusters+ "_with_suspects"

# %%
data= pd.read_csv("data/clusters/" + filename + ".csv").drop_duplicates()

# %%
data[data["liar_caught"] == False][data["N"] == 12]
# Out:
# /home/sabrina/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       N  c1  c2  liar_caught
# 120  12   4   8        False
# 140  12   3   9        False
# 160  12   2  10        False
# 161  12  10   2        False
# 180  12   1  11        False
# 181  12  11   1        False

# %%
data[["N", "liar_caught"]].groupby(["N", "liar_caught"]).size().unstack(fill_value=0).reset_index()
# Out:
# liar_caught   N  False  True
# 0            11      8     2
# 1            12      6     5
# 2            13      8     4
# 3            14     10     3
# 4            15      8     6
# 5            16     10     5
# 6            17     12     4
# 7            18     10     7
# 8            19     12     6
# 9            20     14     5
# 10           21     12     8
# 11           22     14     7
# 12           23     16     6
# 13           24     14     9
# 14           25     16     8

# %%
fig, ax = plt.subplots(figsize=(20, 10))
data[["N", "liar_caught"]].groupby(["N", "liar_caught"]).size().unstack(fill_value=0).reset_index()\
    .plot.bar(stacked=True, ax=ax, x="N", title="How often a liar got caught infiltrating "+nbClusters+" clusters at once")

# %%
fig.savefig('graphs/clusters/'+filename+'.png')

# %%
data["imbalance"] = (data["c1"]/data["c2"]).round(2)
data[data["imbalance"] <= 1]
# Out:
#        N  c1  c2  liar_caught  imbalance
# 0     11   5   6        False       0.83
# 12    11   4   7        False       0.57
# 24    11   3   8        False       0.38
# 36    11   2   9        False       0.22
# 48    11   1  10        False       0.10
# 60    12   6   6         True       1.00
# 100   12   5   7         True       0.71
# 120   12   4   8        False       0.50
# 140   12   3   9        False       0.33
# 160   12   2  10        False       0.20
# 180   12   1  11        False       0.09
# 200   13   6   7         True       0.86
# 212   13   5   8        False       0.62
# 224   13   4   9        False       0.44
# 236   13   3  10        False       0.30
# 248   13   2  11        False       0.18
# 260   13   1  12        False       0.08
# 272   14   7   7         True       1.00
# 320   14   6   8        False       0.75
# 340   14   5   9        False       0.56
# 360   14   4  10        False       0.40
# 380   14   3  11        False       0.27
# 400   14   2  12        False       0.17
# 420   14   1  13        False       0.08
# 440   15   7   8         True       0.88
# 452   15   6   9         True       0.67
# 464   15   5  10        False       0.50
# 476   15   4  11        False       0.36
# 488   15   3  12        False       0.25
# 500   15   2  13        False       0.15
# ...   ..  ..  ..          ...        ...
# 1860  23   6  17        False       0.35
# 1872  23   5  18        False       0.28
# 1884  23   4  19        False       0.21
# 1896  23   3  20        False       0.15
# 1908  23   2  21        False       0.10
# 1920  23   1  22        False       0.05
# 1932  24  12  12         True       1.00
# 2020  24  11  13         True       0.85
# 2040  24  10  14         True       0.71
# 2060  24   9  15         True       0.60
# 2080  24   8  16        False       0.50
# 2100  24   7  17        False       0.41
# 2120  24   6  18        False       0.33
# 2140  24   5  19        False       0.26
# 2160  24   4  20        False       0.20
# 2180  24   3  21        False       0.14
# 2200  24   2  22        False       0.09
# 2220  24   1  23        False       0.04
# 2240  25  12  13         True       0.92
# 2252  25  11  14         True       0.79
# 2264  25  10  15         True       0.67
# 2276  25   9  16        False       0.56
# 2288  25   8  17        False       0.47
# 2300  25   7  18        False       0.39
# 2312  25   6  19        False       0.32
# 2324  25   5  20        False       0.25
# 2336  25   4  21        False       0.19
# 2348  25   3  22        False       0.14
# 2360  25   2  23        False       0.09
# 2372  25   1  24        False       0.04
#
# [131 rows x 5 columns]

# %%
fig1, ax1 = plt.subplots(figsize=(25, 15))
data[["imbalance", "liar_caught"]].drop_duplicates()\
    .groupby(["imbalance", "liar_caught"]).size().unstack(fill_value=0).reset_index()\
    .plot.bar(stacked=True, ax=ax1, x="imbalance", title="Node imbalance between "+nbClusters+" clusters")

# %%
fig1.savefig('graphs/clusters/'+filename+'_cluster_ratio.png')
