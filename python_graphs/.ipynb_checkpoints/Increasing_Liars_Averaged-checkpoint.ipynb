# %% [markdown]
# # Increasing number of liars averaged over 100

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("data/fixed_lies/test_map_fixed_lies_x_liars_clustered_100.csv")

# %%
data
# Out:
#        node  is_liar  is_blacklisted    lie  lieClusterSize
# 0        N0    False           False      0               5
# 1        N1    False           False      0               5
# 2        N2    False           False      0               5
# 3        N3    False           False      0               5
# 4        N4    False           False      0               5
# 5        N5    False           False      0               5
# 6        N6    False           False      0               5
# 7        N7    False           False      0               5
# 8        N8    False           False      0               5
# 9       N10     True            True  19401               5
# 10      N10     True            True  37150               5
# 11      N10     True            True  15785               5
# 12      N10     True            True  28834               5
# 13      N10     True            True  13104               5
# 14      N10     True            True  39147               5
# 15      N10     True            True  47560               5
# 16      N10     True            True  35145               5
# 17      N10     True            True  12492               5
# 18      N10     True            True  42398               5
# 19      N10     True            True  23359               5
# 20      N10     True            True  12877               5
# 21      N10     True            True  35772               5
# 22      N10     True            True   4480               5
# 23      N10     True            True  48168               5
# 24      N10     True            True  49404               5
# 25      N10     True            True  15337               5
# 26      N10     True            True  44686               5
# 27      N10     True            True   7272               5
# 28      N10     True            True  24563               5
# 29      N10     True            True  47728               5
# ...     ...      ...             ...    ...             ...
# 622670  N97     True            True  35144              33
# 622671  N97     True            True  22399              33
# 622672  N97     True            True  38423              33
# 622673  N97     True            True   1140              33
# 622674  N97     True            True  14777              33
# 622675  N97     True            True  41082              33
# 622676  N97     True            True  43750              33
# 622677  N97     True            True  21268              33
# 622678  N97     True            True  46332              33
# 622679  N97     True            True  41536              33
# 622680  N97     True            True  44381              33
# 622681  N97     True            True  29080              33
# 622682  N97     True            True  12691              33
# 622683  N97     True            True  44606              33
# 622684  N97     True            True  23131              33
# 622685  N97     True            True  48463              33
# 622686  N97     True            True  41581              33
# 622687  N97     True            True  33453              33
# 622688  N97     True            True  34143              33
# 622689  N97     True            True  22720              33
# 622690  N97     True            True  26919              33
# 622691  N97     True            True  49630              33
# 622692  N97     True            True  49877              33
# 622693  N97     True            True  47622              33
# 622694  N97     True            True  18986              33
# 622695  N97     True            True  48140              33
# 622696  N97     True            True  35983              33
# 622697  N97     True            True  13125              33
# 622698  N98    False           False      0              33
# 622699  N99    False           False      0              33
#
# [622700 rows x 5 columns]

# %%
data["grouped"] = list(zip(data.is_liar, data.is_blacklisted))
grouped_data = data[["node", "grouped", "lieClusterSize"]]

# %%
grouped_data
# Out:
#        node         grouped  lieClusterSize
# 0        N0  (False, False)               5
# 1        N1  (False, False)               5
# 2        N2  (False, False)               5
# 3        N3  (False, False)               5
# 4        N4  (False, False)               5
# 5        N5  (False, False)               5
# 6        N6  (False, False)               5
# 7        N7  (False, False)               5
# 8        N8  (False, False)               5
# 9       N10    (True, True)               5
# 10      N10    (True, True)               5
# 11      N10    (True, True)               5
# 12      N10    (True, True)               5
# 13      N10    (True, True)               5
# 14      N10    (True, True)               5
# 15      N10    (True, True)               5
# 16      N10    (True, True)               5
# 17      N10    (True, True)               5
# 18      N10    (True, True)               5
# 19      N10    (True, True)               5
# 20      N10    (True, True)               5
# 21      N10    (True, True)               5
# 22      N10    (True, True)               5
# 23      N10    (True, True)               5
# 24      N10    (True, True)               5
# 25      N10    (True, True)               5
# 26      N10    (True, True)               5
# 27      N10    (True, True)               5
# 28      N10    (True, True)               5
# 29      N10    (True, True)               5
# ...     ...             ...             ...
# 622670  N97    (True, True)              33
# 622671  N97    (True, True)              33
# 622672  N97    (True, True)              33
# 622673  N97    (True, True)              33
# 622674  N97    (True, True)              33
# 622675  N97    (True, True)              33
# 622676  N97    (True, True)              33
# 622677  N97    (True, True)              33
# 622678  N97    (True, True)              33
# 622679  N97    (True, True)              33
# 622680  N97    (True, True)              33
# 622681  N97    (True, True)              33
# 622682  N97    (True, True)              33
# 622683  N97    (True, True)              33
# 622684  N97    (True, True)              33
# 622685  N97    (True, True)              33
# 622686  N97    (True, True)              33
# 622687  N97    (True, True)              33
# 622688  N97    (True, True)              33
# 622689  N97    (True, True)              33
# 622690  N97    (True, True)              33
# 622691  N97    (True, True)              33
# 622692  N97    (True, True)              33
# 622693  N97    (True, True)              33
# 622694  N97    (True, True)              33
# 622695  N97    (True, True)              33
# 622696  N97    (True, True)              33
# 622697  N97    (True, True)              33
# 622698  N98  (False, False)              33
# 622699  N99  (False, False)              33
#
# [622700 rows x 3 columns]

# %%
grouped_by_node = grouped_data.groupby(["node", "lieClusterSize"]).agg(lambda x: set(x.values.tolist()))

# %%
grouped_by_node["nb_situations"] = grouped_by_node['grouped'].map(lambda x: len(x))

# %%
grouped_by_node.sort_values(by="nb_situations", ascending=False)
# Out:
#                                                            grouped  \
# node lieClusterSize
# N24  33              {(True, False), (False, False), (True, True)}
# N30  33              {(True, False), (False, False), (True, True)}
# N7   33              {(True, False), (False, False), (True, True)}
# N3   33              {(True, False), (False, False), (True, True)}
# N82  33              {(True, False), (False, False), (True, True)}
# N47  33              {(True, False), (False, False), (True, True)}
# N29  33              {(True, False), (False, False), (True, True)}
# N83  33              {(True, False), (False, False), (True, True)}
# N28  33              {(True, False), (False, False), (True, True)}
# N69  33              {(True, False), (False, False), (True, True)}
# N48  33              {(True, False), (False, False), (True, True)}
# N27  33              {(True, False), (False, False), (True, True)}
# N49  33              {(True, False), (False, False), (True, True)}
# N26  33              {(True, False), (False, False), (True, True)}
# N85  33              {(True, False), (False, False), (True, True)}
# N68  33              {(True, False), (False, False), (True, True)}
# N25  33              {(True, False), (False, False), (True, True)}
# N86  33              {(True, False), (False, False), (True, True)}
# N5   33              {(True, False), (False, False), (True, True)}
# N74  33              {(True, False), (False, False), (True, True)}
# N67  33              {(True, False), (False, False), (True, True)}
# N87  33              {(True, False), (False, False), (True, True)}
# N23  33              {(True, False), (False, False), (True, True)}
# N50  33              {(True, False), (False, False), (True, True)}
# N22  33              {(True, False), (False, False), (True, True)}
# N88  33              {(True, False), (False, False), (True, True)}
# N66  33              {(True, False), (False, False), (True, True)}
# N46  33              {(True, False), (False, False), (True, True)}
# N70  33              {(True, False), (False, False), (True, True)}
# N51  33              {(True, False), (False, False), (True, True)}
# ...                                                            ...
# N37  10                             {(False, False), (True, True)}
#      5                              {(False, False), (True, True)}
# N36  20                             {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      5                              {(False, False), (True, True)}
# N35  20                             {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      5                              {(False, False), (True, True)}
# N40  5                              {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      20                             {(False, False), (True, True)}
# N41  5                              {(False, False), (True, True)}
# N46  20                             {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      5                              {(False, False), (True, True)}
# N45  20                             {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      5                              {(False, False), (True, True)}
# N44  20                             {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      5                              {(False, False), (True, True)}
# N43  20                             {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      5                              {(False, False), (True, True)}
# N42  20                             {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
#      5                              {(False, False), (True, True)}
# N41  20                             {(False, False), (True, True)}
#      10                             {(False, False), (True, True)}
# N99  33                             {(False, False), (True, True)}
#
#                      nb_situations
# node lieClusterSize
# N24  33                          3
# N30  33                          3
# N7   33                          3
# N3   33                          3
# N82  33                          3
# N47  33                          3
# N29  33                          3
# N83  33                          3
# N28  33                          3
# N69  33                          3
# N48  33                          3
# N27  33                          3
# N49  33                          3
# N26  33                          3
# N85  33                          3
# N68  33                          3
# N25  33                          3
# N86  33                          3
# N5   33                          3
# N74  33                          3
# N67  33                          3
# N87  33                          3
# N23  33                          3
# N50  33                          3
# N22  33                          3
# N88  33                          3
# N66  33                          3
# N46  33                          3
# N70  33                          3
# N51  33                          3
# ...                            ...
# N37  10                          2
#      5                           2
# N36  20                          2
#      10                          2
#      5                           2
# N35  20                          2
#      10                          2
#      5                           2
# N40  5                           2
#      10                          2
#      20                          2
# N41  5                           2
# N46  20                          2
#      10                          2
#      5                           2
# N45  20                          2
#      10                          2
#      5                           2
# N44  20                          2
#      10                          2
#      5                           2
# N43  20                          2
#      10                          2
#      5                           2
# N42  20                          2
#      10                          2
#      5                           2
# N41  20                          2
#      10                          2
# N99  33                          2
#
# [400 rows x 2 columns]

# %%
data[["node", "lieClusterSize","is_liar", "is_blacklisted"]]\
.groupby(["is_liar", "is_blacklisted", "lieClusterSize"]).count()/100
# Out:
#                                           node
# is_liar is_blacklisted lieClusterSize
# False   False          5                 67.00
#                        10                67.00
#                        20                67.00
#                        33                67.00
# True    False          33              1111.89
#         True           5                485.00
#                        10               945.00
#                        20              1790.00
#                        33              1627.11

# %%
lies = data[["lieClusterSize","is_blacklisted"]][data["lie"] > 0]

# %%
lies.groupby("lieClusterSize").agg(lambda x: set(x.values.tolist())).reset_index()
# Out:
#    lieClusterSize is_blacklisted
# 0               5         {True}
# 1              10         {True}
# 2              20         {True}
# 3              33  {False, True}

# %%
bl_by_lie = lies.groupby(['lieClusterSize', 'is_blacklisted']).size().unstack(fill_value=0).reset_index()

# %%
bl_by_lie
# Out:
# is_blacklisted  lieClusterSize   False    True
# 0                            5       0   48500
# 1                           10       0   94500
# 2                           20       0  179000
# 3                           33  111189  162711

# %%
fig, ax = plt.subplots(figsize=(20, 10))
bl_by_lie[["lieClusterSize", True, False]]\
.groupby("lieClusterSize").sum().reset_index().plot.bar(stacked=True, ax=ax, x="lieClusterSize")

# %%
fig.savefig('graphs/fixed_lies/test_map_fixed_lies_x_liars_clustered_100.png')
