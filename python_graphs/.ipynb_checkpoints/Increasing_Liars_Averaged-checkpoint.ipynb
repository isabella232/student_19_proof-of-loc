# %% [markdown]
# # Increasing number of liars averaged over 100

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("data/fixed_lies/test_map_fixed_lies_x_liars_clustered_100_with_suspects.csv")

# %%
data
# Out:
#        node  is_liar  is_blacklisted    lie  lieClusterSize
# 0        N0     True            True   3347               5
# 1        N0     True            True  25595               5
# 2        N0     True            True  40479               5
# 3        N0     True            True  21124               5
# 4        N0     True            True  49416               5
# 5        N0     True            True  24042               5
# 6        N0     True            True  31909               5
# 7        N0     True            True  34786               5
# 8        N0     True            True   1363               5
# 9        N0     True            True  26766               5
# 10       N0     True            True  23267               5
# 11       N0     True            True  13575               5
# 12       N0     True            True  46854               5
# 13       N0     True            True  26854               5
# 14       N0     True            True  33769               5
# 15       N0     True            True  40226               5
# 16       N0     True            True  41632               5
# 17       N0     True            True  49308               5
# 18       N0     True            True   8251               5
# 19       N0     True            True  38331               5
# 20       N0     True            True   8780               5
# 21       N0     True            True  43126               5
# 22       N0     True            True  32415               5
# 23       N0     True            True  46933               5
# 24       N0     True            True  46069               5
# 25       N0     True            True  29614               5
# 26       N0     True            True  49950               5
# 27       N0     True            True  15363               5
# 28       N0     True            True  46741               5
# 29       N0     True            True  43778               5
# ...     ...      ...             ...    ...             ...
# 622670  N70    False           False      0              33
# 622671  N71    False           False      0              33
# 622672  N72    False           False      0              33
# 622673  N73    False           False      0              33
# 622674  N74    False           False      0              33
# 622675  N75    False           False      0              33
# 622676  N76    False           False      0              33
# 622677  N77    False           False      0              33
# 622678  N78    False           False      0              33
# 622679  N79    False           False      0              33
# 622680  N80    False           False      0              33
# 622681  N81    False           False      0              33
# 622682  N82    False           False      0              33
# 622683  N83    False           False      0              33
# 622684  N84    False           False      0              33
# 622685  N85    False           False      0              33
# 622686  N86    False           False      0              33
# 622687  N87    False           False      0              33
# 622688  N88    False           False      0              33
# 622689  N89    False           False      0              33
# 622690  N90    False           False      0              33
# 622691  N91    False           False      0              33
# 622692  N92    False           False      0              33
# 622693  N93    False           False      0              33
# 622694  N94    False           False      0              33
# 622695  N95    False           False      0              33
# 622696  N96    False           False      0              33
# 622697  N97    False           False      0              33
# 622698  N98    False           False      0              33
# 622699  N99    False           False      0              33
#
# [622700 rows x 5 columns]

# %%
data["grouped"] = list(zip(data.is_liar, data.is_blacklisted))
grouped_data = data[["node", "grouped", "lieClusterSize"]]

# %%
grouped_data
# Out:
#        node         grouped  lieClusterSize
# 0        N0    (True, True)               5
# 1        N0    (True, True)               5
# 2        N0    (True, True)               5
# 3        N0    (True, True)               5
# 4        N0    (True, True)               5
# 5        N0    (True, True)               5
# 6        N0    (True, True)               5
# 7        N0    (True, True)               5
# 8        N0    (True, True)               5
# 9        N0    (True, True)               5
# 10       N0    (True, True)               5
# 11       N0    (True, True)               5
# 12       N0    (True, True)               5
# 13       N0    (True, True)               5
# 14       N0    (True, True)               5
# 15       N0    (True, True)               5
# 16       N0    (True, True)               5
# 17       N0    (True, True)               5
# 18       N0    (True, True)               5
# 19       N0    (True, True)               5
# 20       N0    (True, True)               5
# 21       N0    (True, True)               5
# 22       N0    (True, True)               5
# 23       N0    (True, True)               5
# 24       N0    (True, True)               5
# 25       N0    (True, True)               5
# 26       N0    (True, True)               5
# 27       N0    (True, True)               5
# 28       N0    (True, True)               5
# 29       N0    (True, True)               5
# ...     ...             ...             ...
# 622670  N70  (False, False)              33
# 622671  N71  (False, False)              33
# 622672  N72  (False, False)              33
# 622673  N73  (False, False)              33
# 622674  N74  (False, False)              33
# 622675  N75  (False, False)              33
# 622676  N76  (False, False)              33
# 622677  N77  (False, False)              33
# 622678  N78  (False, False)              33
# 622679  N79  (False, False)              33
# 622680  N80  (False, False)              33
# 622681  N81  (False, False)              33
# 622682  N82  (False, False)              33
# 622683  N83  (False, False)              33
# 622684  N84  (False, False)              33
# 622685  N85  (False, False)              33
# 622686  N86  (False, False)              33
# 622687  N87  (False, False)              33
# 622688  N88  (False, False)              33
# 622689  N89  (False, False)              33
# 622690  N90  (False, False)              33
# 622691  N91  (False, False)              33
# 622692  N92  (False, False)              33
# 622693  N93  (False, False)              33
# 622694  N94  (False, False)              33
# 622695  N95  (False, False)              33
# 622696  N96  (False, False)              33
# 622697  N97  (False, False)              33
# 622698  N98  (False, False)              33
# 622699  N99  (False, False)              33
#
# [622700 rows x 3 columns]

# %%
grouped_by_node = grouped_data.groupby(["node", "lieClusterSize"]).agg(lambda x: set(x.values.tolist()))

# %%
grouped_by_node["nb_situations"] = grouped_by_node['grouped'].map(lambda x: len(x))

# %%
grouped_by_node.sort_values(by="nb_situations", ascending=False)
# Out:
#                                                            grouped  \
# node lieClusterSize
# N31  33              {(True, False), (False, False), (True, True)}
# N32  33              {(True, False), (False, False), (True, True)}
# N64  33              {(True, False), (False, False), (True, True)}
# N5   33                              {(True, False), (True, True)}
# N8   33                              {(True, False), (True, True)}
# N30  33                              {(True, False), (True, True)}
# N3   33                              {(True, False), (True, True)}
# N29  33                              {(True, False), (True, True)}
# N14  33                              {(True, False), (True, True)}
# N26  33                              {(True, False), (True, True)}
# N25  33                              {(True, False), (True, True)}
# N23  33                              {(True, False), (True, True)}
# N22  33                              {(True, False), (True, True)}
# N20  33                              {(True, False), (True, True)}
# N19  33                              {(True, False), (True, True)}
# N15  33                              {(True, False), (True, True)}
# N27  33                              {(True, False), (True, True)}
# N99  33                            {(True, False), (False, False)}
# N13  33                              {(True, False), (True, True)}
# N11  33                              {(True, False), (True, True)}
# N6   33                              {(True, False), (True, True)}
# N0   33                              {(True, False), (True, True)}
# N1   33                              {(True, False), (True, True)}
# N12  33                              {(True, False), (True, True)}
# N65  5                                            {(False, False)}
# N74  33                                           {(False, False)}
# N76  5                                            {(False, False)}
# N75  33                                           {(False, False)}
#      20                                           {(False, False)}
#      10                                           {(False, False)}
# ...                                                            ...
# N45  20                                           {(False, False)}
# N48  5                                            {(False, False)}
# N45  10                                           {(False, False)}
#      5                                            {(False, False)}
# N44  33                                           {(False, False)}
#      20                                           {(False, False)}
#      10                                           {(False, False)}
#      5                                            {(False, False)}
# N43  33                                           {(False, False)}
# N47  33                                           {(False, False)}
# N48  10                                           {(False, False)}
# N52  10                                           {(False, False)}
# N50  10                                           {(False, False)}
# N52  5                                            {(False, False)}
# N51  33                                           {(False, False)}
#      20                                           {(False, False)}
#      10                                           {(False, False)}
#      5                                            {(False, False)}
# N50  33                                           {(False, False)}
#      20                                           {(False, False)}
#      5                                            {(False, False)}
# N48  20                                           {(False, False)}
# N5   20                                             {(True, True)}
#      10                                             {(True, True)}
# N49  33                                           {(False, False)}
#      20                                           {(False, False)}
#      10                                           {(False, False)}
#      5                                            {(False, False)}
# N48  33                                           {(False, False)}
# N6   20                                             {(True, True)}
#
#                      nb_situations
# node lieClusterSize
# N31  33                          3
# N32  33                          3
# N64  33                          3
# N5   33                          2
# N8   33                          2
# N30  33                          2
# N3   33                          2
# N29  33                          2
# N14  33                          2
# N26  33                          2
# N25  33                          2
# N23  33                          2
# N22  33                          2
# N20  33                          2
# N19  33                          2
# N15  33                          2
# N27  33                          2
# N99  33                          2
# N13  33                          2
# N11  33                          2
# N6   33                          2
# N0   33                          2
# N1   33                          2
# N12  33                          2
# N65  5                           1
# N74  33                          1
# N76  5                           1
# N75  33                          1
#      20                          1
#      10                          1
# ...                            ...
# N45  20                          1
# N48  5                           1
# N45  10                          1
#      5                           1
# N44  33                          1
#      20                          1
#      10                          1
#      5                           1
# N43  33                          1
# N47  33                          1
# N48  10                          1
# N52  10                          1
# N50  10                          1
# N52  5                           1
# N51  33                          1
#      20                          1
#      10                          1
#      5                           1
# N50  33                          1
#      20                          1
#      5                           1
# N48  20                          1
# N5   20                          1
#      10                          1
# N49  33                          1
#      20                          1
#      10                          1
#      5                           1
# N48  33                          1
# N6   20                          1
#
# [342 rows x 2 columns]

# %%
data[["node", "lieClusterSize","is_liar", "is_blacklisted"]]\
.groupby(["is_liar", "is_blacklisted", "lieClusterSize"]).count()
# Out:
#                                          node
# is_liar is_blacklisted lieClusterSize
# False   False          5                 6700
#                        10                6700
#                        20                6700
#                        33                6700
# True    False          33               88960
#         True           5                48500
#                        10               94500
#                        20              179000
#                        33              184940

# %%
lies = data[["node","lieClusterSize","is_blacklisted"]][data["lie"] > 0]

# %%
lists = lies.groupby("lieClusterSize").agg(lambda x: set(x.values.tolist())).reset_index()
lists
# Out:
#    lieClusterSize                                               node  \
# 0               5                               {N1, N4, N0, N2, N3}
# 1              10           {N1, N5, N9, N7, N8, N4, N0, N6, N2, N3}
# 2              20  {N17, N10, N11, N12, N18, N19, N3, N1, N5, N9,...
# 3              33  {N17, N10, N29, N11, N12, N18, N19, N27, N3, N...
#
#   is_blacklisted
# 0         {True}
# 1         {True}
# 2         {True}
# 3  {False, True}

# %%
bl_by_lie = lies.groupby(['lieClusterSize', 'is_blacklisted']).size().unstack(fill_value=0).reset_index()

# %%
plotdf = bl_by_lie[["lieClusterSize", True, False]]\
.groupby("lieClusterSize").sum().reset_index()
plotdf
# Out:
# is_blacklisted  lieClusterSize    True  False
# 0                            5   48500      0
# 1                           10   94500      0
# 2                           20  179000      0
# 3                           33  184940  88960

# %%
fig, ax = plt.subplots(figsize=(20, 10))
bl_by_lie[["lieClusterSize", True, False]]\
.groupby("lieClusterSize").sum().reset_index().plot.bar(stacked=True, ax=ax, x="lieClusterSize",
    title="Proportion of liars blacklisted given the number of randomly selected liars in a network over 100 sets, with enhanced balcklisting")
ax.set_ylabel("Number of liars blacklisted")
ax.set_xlabel("Number of liars in network")
# Out:
# Text(0.5, 0, 'Number of liars in network')

# %%
fig.savefig('graphs/fixed_lies/test_map_fixed_lies_x_liars_random_100.png')
