# %% [markdown]
# # Fixed Lies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("data/fixed_lies/test_map_fixed_lies_x_liars_clustered_100_with_suspects.csv")

# %%
data
# Out:
#      node  is_liar  is_blacklisted    lie  lieClusterSize
# 0      N0    False           False      0               5
# 1      N1    False           False      0               5
# 2      N2    False           False      0               5
# 3      N3    False           False      0               5
# 4      N4    False           False      0               5
# 5      N5    False           False      0               5
# 6      N8     True            True  23418               5
# 7      N8     True            True   1502               5
# 8      N8     True            True  16154               5
# 9      N8     True            True  20594               5
# 10     N8     True            True  26180               5
# 11     N8     True            True  32357               5
# 12     N8     True            True  42863               5
# 13     N8     True            True  24729               5
# 14     N8     True            True   3599               5
# 15     N8     True            True  41995               5
# 16     N8     True            True  31078               5
# 17     N8     True            True   1849               5
# 18     N8     True            True  41033               5
# 19     N8     True            True  12432               5
# 20     N8     True            True  39086               5
# 21     N8     True            True  29014               5
# 22     N8     True            True   7978               5
# 23     N8     True            True  13723               5
# 24     N8     True            True  22932               5
# 25     N8     True            True   2920               5
# 26     N8     True            True  38731               5
# 27     N8     True            True   4446               5
# 28     N8     True            True   6678               5
# 29     N8     True            True   2979               5
# ...   ...      ...             ...    ...             ...
# 6197  N96     True            True  13238              33
# 6198  N96     True            True  26867              33
# 6199  N96     True            True  24040              33
# 6200  N96     True            True  11167              33
# 6201  N96     True            True  36248              33
# 6202  N96     True            True  25126              33
# 6203  N96     True            True  32883              33
# 6204  N96     True            True   1690              33
# 6205  N96     True            True  24487              33
# 6206  N96     True            True  10202              33
# 6207  N96     True            True  30126              33
# 6208  N96     True            True  24738              33
# 6209  N96     True            True  34117              33
# 6210  N96     True            True  18966              33
# 6211  N96     True            True  11350              33
# 6212  N96     True            True  49991              33
# 6213  N96     True            True   5480              33
# 6214  N96     True            True  39031              33
# 6215  N96     True            True  43590              33
# 6216  N96     True            True  40665              33
# 6217  N96     True            True   5224              33
# 6218  N96     True            True  20117              33
# 6219  N96     True            True  23445              33
# 6220  N96     True            True  33211              33
# 6221  N96     True            True   3607              33
# 6222  N96     True            True   2879              33
# 6223  N96     True            True   2456              33
# 6224  N97    False           False      0              33
# 6225  N98    False           False      0              33
# 6226  N99    False           False      0              33
#
# [6227 rows x 5 columns]

# %%
data["grouped"] = list(zip(data.is_liar, data.is_blacklisted))
grouped_data = data[["node", "grouped", "lieClusterSize"]]

# %%
grouped_data
# Out:
#      node         grouped  lieClusterSize
# 0      N0  (False, False)               5
# 1      N1  (False, False)               5
# 2      N2  (False, False)               5
# 3      N3  (False, False)               5
# 4      N4  (False, False)               5
# 5      N5  (False, False)               5
# 6      N8    (True, True)               5
# 7      N8    (True, True)               5
# 8      N8    (True, True)               5
# 9      N8    (True, True)               5
# 10     N8    (True, True)               5
# 11     N8    (True, True)               5
# 12     N8    (True, True)               5
# 13     N8    (True, True)               5
# 14     N8    (True, True)               5
# 15     N8    (True, True)               5
# 16     N8    (True, True)               5
# 17     N8    (True, True)               5
# 18     N8    (True, True)               5
# 19     N8    (True, True)               5
# 20     N8    (True, True)               5
# 21     N8    (True, True)               5
# 22     N8    (True, True)               5
# 23     N8    (True, True)               5
# 24     N8    (True, True)               5
# 25     N8    (True, True)               5
# 26     N8    (True, True)               5
# 27     N8    (True, True)               5
# 28     N8    (True, True)               5
# 29     N8    (True, True)               5
# ...   ...             ...             ...
# 6197  N96    (True, True)              33
# 6198  N96    (True, True)              33
# 6199  N96    (True, True)              33
# 6200  N96    (True, True)              33
# 6201  N96    (True, True)              33
# 6202  N96    (True, True)              33
# 6203  N96    (True, True)              33
# 6204  N96    (True, True)              33
# 6205  N96    (True, True)              33
# 6206  N96    (True, True)              33
# 6207  N96    (True, True)              33
# 6208  N96    (True, True)              33
# 6209  N96    (True, True)              33
# 6210  N96    (True, True)              33
# 6211  N96    (True, True)              33
# 6212  N96    (True, True)              33
# 6213  N96    (True, True)              33
# 6214  N96    (True, True)              33
# 6215  N96    (True, True)              33
# 6216  N96    (True, True)              33
# 6217  N96    (True, True)              33
# 6218  N96    (True, True)              33
# 6219  N96    (True, True)              33
# 6220  N96    (True, True)              33
# 6221  N96    (True, True)              33
# 6222  N96    (True, True)              33
# 6223  N96    (True, True)              33
# 6224  N97  (False, False)              33
# 6225  N98  (False, False)              33
# 6226  N99  (False, False)              33
#
# [6227 rows x 3 columns]

# %%
grouped_by_node = grouped_data.groupby(["node", "lieClusterSize"]).agg(lambda x: set(x.values.tolist()))

# %%
grouped_by_node["nb_situations"] = grouped_by_node['grouped'].map(lambda x: len(x))

# %%
grouped_by_node
# Out:
#                               grouped  nb_situations
# node lieClusterSize
# N0   5               {(False, False)}              1
#      10              {(False, False)}              1
#      20              {(False, False)}              1
#      33              {(False, False)}              1
# N1   5               {(False, False)}              1
#      10              {(False, False)}              1
#      20              {(False, False)}              1
#      33              {(False, False)}              1
# N10  5               {(False, False)}              1
#      10              {(False, False)}              1
#      20              {(False, False)}              1
#      33              {(False, False)}              1
# N11  5               {(False, False)}              1
#      10              {(False, False)}              1
#      20              {(False, False)}              1
#      33              {(False, False)}              1
# N12  5               {(False, False)}              1
#      10              {(False, False)}              1
#      20              {(False, False)}              1
#      33              {(False, False)}              1
# N13  5               {(False, False)}              1
#      10              {(False, False)}              1
#      20              {(False, False)}              1
#      33              {(False, False)}              1
# N14  5               {(False, False)}              1
#      10              {(False, False)}              1
#      20              {(False, False)}              1
#      33              {(False, False)}              1
# N15  33               {(True, False)}              1
# N16  5               {(False, False)}              1
# ...                               ...            ...
# N90  33              {(False, False)}              1
# N91  33               {(True, False)}              1
# N92  5               {(False, False)}              1
#      10              {(False, False)}              1
#      20              {(False, False)}              1
#      33              {(False, False)}              1
# N93  5               {(False, False)}              1
#      10              {(False, False)}              1
#      20              {(False, False)}              1
#      33              {(False, False)}              1
# N94  20                {(True, True)}              1
#      33               {(True, False)}              1
# N95  5               {(False, False)}              1
#      10              {(False, False)}              1
#      20              {(False, False)}              1
#      33              {(False, False)}              1
# N96  20                {(True, True)}              1
#      33                {(True, True)}              1
# N97  5               {(False, False)}              1
#      10              {(False, False)}              1
#      20              {(False, False)}              1
#      33              {(False, False)}              1
# N98  5               {(False, False)}              1
#      10              {(False, False)}              1
#      20              {(False, False)}              1
#      33              {(False, False)}              1
# N99  5               {(False, False)}              1
#      10              {(False, False)}              1
#      20              {(False, False)}              1
#      33              {(False, False)}              1
#
# [336 rows x 2 columns]

# %%
data[["node", "lieClusterSize","is_liar", "is_blacklisted"]]\
.groupby(["is_liar", "is_blacklisted", "lieClusterSize"]).count()
# Out:
#                                        node
# is_liar is_blacklisted lieClusterSize
# False   False          5                 67
#                        10                67
#                        20                67
#                        33                67
# True    False          33               581
#         True           5                485
#                        10               945
#                        20              1790
#                        33              2158

# %%
lies = data[["node","lieClusterSize","is_blacklisted"]][data["lie"] > 0]\
            .drop_duplicates()[["lieClusterSize","is_blacklisted"]]

# %%
lies
# Out:
#       lieClusterSize  is_blacklisted
# 6                  5            True
# 115                5            True
# 233                5            True
# 332                5            True
# 444                5            True
# 558               10            True
# 667               10            True
# 775               10            True
# 875               10            True
# 978               10            True
# 1075              10            True
# 1169              10            True
# 1275              10            True
# 1370              10            True
# 1462              10            True
# 1570              20            True
# 1669              20            True
# 1767              20            True
# 1874              20            True
# 1972              20            True
# 2071              20            True
# 2168              20            True
# 2262              20            True
# 2357              20            True
# 2448              20            True
# 2542              20            True
# 2634              20            True
# 2724              20            True
# 2811              20            True
# 2910              20            True
# ...              ...             ...
# 3727              33           False
# 3825              33            True
# 3922              33            True
# 4016              33            True
# 4111              33            True
# 4205              33            True
# 4298              33           False
# 4390              33            True
# 4480              33            True
# 4569              33            True
# 4656              33            True
# 4742              33            True
# 4827              33            True
# 4914              33            True
# 4997              33           False
# 5083              33            True
# 5167              33            True
# 5249              33           False
# 5328              33            True
# 5406              33            True
# 5484              33            True
# 5561              33            True
# 5647              33            True
# 5724              33            True
# 5798              33            True
# 5872              33            True
# 5944              33            True
# 6017              33           False
# 6088              33           False
# 6157              33            True
#
# [68 rows x 2 columns]

# %%
lies.groupby("lieClusterSize").agg(lambda x: set(x.values.tolist())).reset_index()
# Out:
#    lieClusterSize is_blacklisted
# 0               5         {True}
# 1              10         {True}
# 2              20         {True}
# 3              33  {False, True}

# %%
bl_by_lie = lies.groupby(['lieClusterSize', 'is_blacklisted']).size().unstack(fill_value=0).reset_index()

# %%
bl_by_lie
# Out:
# is_blacklisted  lieClusterSize  False  True
# 0                            5      0     5
# 1                           10      0    10
# 2                           20      0    20
# 3                           33      7    26

# %%
fig, ax = plt.subplots(figsize=(20, 10))
bl_by_lie[["lieClusterSize", True, False]]\
.groupby("lieClusterSize").sum().reset_index().plot.bar(
    stacked=True, ax=ax, x="lieClusterSize", 
    title="Proportion of liars blacklisted given the number of selected clustered liars in a network, with suspect balcklisted")

ax.set_ylabel("Number of liars blacklisted")
ax.set_xlabel("Number of liars in network")
# Out:
# Text(0.5, 0, 'Number of liars in network')

# %%
fig.savefig('graphs/fixed_lies/test_map_fixed_lies_x_liars_clusteredts_with_suspec.png')
