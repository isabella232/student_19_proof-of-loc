# %% [markdown]
# # Graphs representing blacklisting in network for growing magnitude of lies
#
# This notebook allows us to create graphs showing how many liars are blacklisted, given a growing the average discreptancy between the true latencies and the lies influencing individual nodes.
#
# The data for these graphs can be collected using the go test **TestVarSizeLiesGraphCreation**.
#
#  The generated graphs can be found under python_graphs/var_lies/graphs/percentage.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#configs
withSuspects = True  #use enhanced blacklisting algorithm
singleVictim = False #liars target single victim
coordinated = False  #liars coordinate (their lies do not contradict each other)
nbNodes = 100
nbLiars = 33
maxLatency = [50,100, 600, 650, 700, 750, 800, 850, 900]
    #the maximum amount by which a lie deviates from the corresponding latency's true value

nbVictims = "all"
if singleVictim:
    nbVictims = "one"

coord = "coordinated"
if not coordinated:
    coord = "uncoordinated"


filename = "test_" + str(nbNodes) + "_nodes_" + str(nbLiars) + "_liars_attack_" + nbVictims +\
    "_distance_" + str(maxLatency[0]) + "_to_" + str(maxLatency[len(maxLatency)-1]) + "_" + coord

if withSuspects:
    filename += "_with_suspects"

# %%
data = pd.read_csv("data/var_lie_size/"+filename+".csv")
data
# Out:
#     max_lie_latency is_liar is_blacklisted
# 0                50    true          false
# 1                50    true          false
# 2                50    true          false
# 3                50    true          false
# 4                50    true          false
# 5                50    true          false
# 6                50    true          false
# 7                50    true          false
# 8                50    true          false
# 9                50    true          false
# 10               50    true          false
# 11               50    true          false
# 12               50    true          false
# 13               50    true          false
# 14               50    true          false
# 15               50    true          false
# 16               50    true          false
# 17               50    true          false
# 18               50    true          false
# 19               50    true          false
# 20               50    true          false
# 21               50    true          false
# 22               50    true          false
# 23               50    true          false
# 24               50    true          false
# 25               50    true          false
# 26               50    true          false
# 27               50    true          false
# 28               50    true          false
# 29               50    true          false
# ..              ...     ...            ...
# 878             900   false          false
# 879             900   false          false
# 880             900   false          false
# 881             900   false          false
# 882             900   false          false
# 883             900   false          false
# 884             900   false          false
# 885             900   false          false
# 886             900   false          false
# 887             900   false          false
# 888             900   false          false
# 889             900   false          false
# 890             900   false          false
# 891             900   false          false
# 892             900   false          false
# 893             900   false          false
# 894             900   false          false
# 895             900   false          false
# 896             900   false          false
# 897             900   false          false
# 898             900   false          false
# 899             900   false          false
# 900             900   false          false
# 901             900   false          false
# 902             900   false          false
# 903             900   false          false
# 904             900   false          false
# 905             900   false          false
# 906             900   false          false
# 907             900   false          false
#
# [908 rows x 3 columns]

# %%
df1 = data.copy()[data["is_liar"] == "true"]
df1b = df1.copy()[df1["is_blacklisted"] == "true"]

# %%
df2 = df1[["max_lie_latency"]]
df2b = df1b[["max_lie_latency"]]

# %%
df2["total"] = 1
df2b["count"] = 1
# Out:
# /home/sabrina/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/sabrina/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df3 = df2.groupby("max_lie_latency").count().reset_index()
df3b = df2b.groupby("max_lie_latency").count().reset_index()

# %%
df3b
# Out:
#   max_lie_latency  count
# 0             600     13
# 1             650     22
# 2             700     29
# 3             750     32
# 4             800     31
# 5             850     32
# 6             900     33

# %%
df3b["proportion"] = df3b["count"]/nbLiars

# %%
df3b
# Out:
#   max_lie_latency  count  proportion
# 0             600     13    0.393939
# 1             650     22    0.666667
# 2             700     29    0.878788
# 3             750     32    0.969697
# 4             800     31    0.939394
# 5             850     32    0.969697
# 6             900     33    1.000000

# %%
fig, ax = plt.subplots(figsize=(20, 10))
df3b.plot(ax=ax, kind='bar', x='max_lie_latency', y='proportion', fontsize=20)
plt.title("Blacklisted malicious nodes proportion according \n to the divergence between true and crafted latencies",
         fontsize=30)
plt.xlabel("magnitude of divergence between true and crafted latencies [microseconds]", fontsize=25)
plt.ylabel("proportion of blacklisted malicious nodes", fontsize=25)
plt.legend(bbox_to_anchor=(0.23, 0.98), loc=1, borderaxespad=0., fontsize=15, title="Proportion liars caught", 
           title_fontsize="20")

plt.show()

# %%
fig.savefig("graphs/var_lie_size/"+filename +".png")
