# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
N = "100"
lie_type = "attack_all_outrageous"

# %%
statuses = {0: "no endpoint blacklisted", 1: "one endpoint blacklisted", 2: "both endpoints blacklisted"}
colors = {"no endpoint blacklisted": "green", 
          "one endpoint blacklisted": "blue", 
          "both endpoints blacklisted": "red"}

# %%
data= pd.read_csv("data/test_"+N+"_nodes_"+lie_type+".csv")[["true_latency", "recorded_latency", "blacklist_status"]]

# %%
data["status"] = data["blacklist_status"][data["blacklist_status"] > -1 ].map(statuses)

# %%
data
# Out:
#       true_latency  recorded_latency  blacklist_status  \
# 0              581             20264                 0
# 1              887             16491                 0
# 2              847              6053                 1
# 3              559             17489                 1
# 4              581             15235                 1
# 5              818             16832                 0
# 6              925              7054                 0
# 7              540              8624                 1
# 8              956              6451                 1
# 9              800             12542                 0
# 10             694             12924                 0
# 11             511             14245                 0
# 12             662              3334                 1
# 13             589              1391                 1
# 14             728              5833                 1
# 15             774             15346                 1
# 16             711              5778                 0
# 17             945              1607                 1
# 18             737             18861                 0
# 19             606             14797                 1
# 20             995             12730                 0
# 21             966              8262                 1
# 22             528              5599                 0
# 23             758             18719                 0
# 24             547              8485                 1
# 25             947             10171                 0
# 26             787             14165                 0
# 27             888             19632                 1
# 28             790              8430                 0
# 29             515             20630                 1
# ...            ...               ...               ...
# 4920           922               922                 0
# 4921           749               749                 0
# 4922           882               882                 0
# 4923           878               878                 0
# 4924           517               517                 0
# 4925           699               699                 0
# 4926           710               710                 0
# 4927           683               683                 0
# 4928           748               748                 0
# 4929           961               961                 0
# 4930           905               905                 0
# 4931           634               634                 0
# 4932           676               676                 0
# 4933           613               613                 0
# 4934           782               782                 0
# 4935           804               804                 0
# 4936           833               833                 0
# 4937           659               659                 0
# 4938           986               986                 0
# 4939           983               983                 0
# 4940           643               643                 0
# 4941           702               702                 0
# 4942           910               910                 0
# 4943           960               960                 0
# 4944           993               993                 0
# 4945           753               753                 0
# 4946           891               891                 0
# 4947           991               991                 0
# 4948           872               872                 0
# 4949           935               935                 0
#
#                         status
# 0      no endpoint blacklisted
# 1      no endpoint blacklisted
# 2     one endpoint blacklisted
# 3     one endpoint blacklisted
# 4     one endpoint blacklisted
# 5      no endpoint blacklisted
# 6      no endpoint blacklisted
# 7     one endpoint blacklisted
# 8     one endpoint blacklisted
# 9      no endpoint blacklisted
# 10     no endpoint blacklisted
# 11     no endpoint blacklisted
# 12    one endpoint blacklisted
# 13    one endpoint blacklisted
# 14    one endpoint blacklisted
# 15    one endpoint blacklisted
# 16     no endpoint blacklisted
# 17    one endpoint blacklisted
# 18     no endpoint blacklisted
# 19    one endpoint blacklisted
# 20     no endpoint blacklisted
# 21    one endpoint blacklisted
# 22     no endpoint blacklisted
# 23     no endpoint blacklisted
# 24    one endpoint blacklisted
# 25     no endpoint blacklisted
# 26     no endpoint blacklisted
# 27    one endpoint blacklisted
# 28     no endpoint blacklisted
# 29    one endpoint blacklisted
# ...                        ...
# 4920   no endpoint blacklisted
# 4921   no endpoint blacklisted
# 4922   no endpoint blacklisted
# 4923   no endpoint blacklisted
# 4924   no endpoint blacklisted
# 4925   no endpoint blacklisted
# 4926   no endpoint blacklisted
# 4927   no endpoint blacklisted
# 4928   no endpoint blacklisted
# 4929   no endpoint blacklisted
# 4930   no endpoint blacklisted
# 4931   no endpoint blacklisted
# 4932   no endpoint blacklisted
# 4933   no endpoint blacklisted
# 4934   no endpoint blacklisted
# 4935   no endpoint blacklisted
# 4936   no endpoint blacklisted
# 4937   no endpoint blacklisted
# 4938   no endpoint blacklisted
# 4939   no endpoint blacklisted
# 4940   no endpoint blacklisted
# 4941   no endpoint blacklisted
# 4942   no endpoint blacklisted
# 4943   no endpoint blacklisted
# 4944   no endpoint blacklisted
# 4945   no endpoint blacklisted
# 4946   no endpoint blacklisted
# 4947   no endpoint blacklisted
# 4948   no endpoint blacklisted
# 4949   no endpoint blacklisted
#
# [4950 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize=(20, 10))
grouped = data.groupby('status')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='true_latency', y='recorded_latency', label=key, color=colors[key])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

plt.show()

# %%
fig.savefig('graphs/'+N+'_nodes_' + lie_type+".png")
